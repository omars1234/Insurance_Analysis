# %% [markdown]
# ## <u>*Calssifications Modelling for age category as a Target Feature*</u>

# %%
# %run 3_EDA.ipynb

# %%
df5=df.copy()
df5.drop(["clm"],axis=1,inplace=True)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)
import seaborn as sns;sns.set()
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
from datetime import datetime,time
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import (
    r2_score,accuracy_score,roc_auc_score,auc,roc_curve,precision_score,
    recall_score,precision_recall_curve,r2_score,classification_report,RocCurveDisplay,
    confusion_matrix,f1_score,ConfusionMatrixDisplay
    )


from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier,XGBRFClassifier
import warnings
from sklearn.ensemble import (
    AdaBoostClassifier,
    RandomForestClassifier,
    GradientBoostingClassifier,BaggingClassifier
)

from hyperopt import fmin,tpe,STATUS_OK,Trials,hp
from sklearn.utils.multiclass import unique_labels
import plotclassification ,plotly
# import matplotlib.pyplot as plt
from yellowbrick.classifier import ClassificationReport

# %% [markdown]
# ### *A.*<br> <u>*Models Preparation :*</u>

# %% [markdown]
# #### *A.1. <br> <u>Classification Models to use :*</u>

# %%
models = {
                "RandomForestClassifier": RandomForestClassifier(),
                "DecisionTreeClassifier": DecisionTreeClassifier(),
                "GradientBoostingClassifier": GradientBoostingClassifier(),
                "XGBClassifier": XGBClassifier(),
                "CatBoostClassifier": CatBoostClassifier(verbose=False),
                "AdaBoostClassifier": AdaBoostClassifier(),
                "BaggingClassifier":BaggingClassifier()
            }

# %% [markdown]
# #### *A.2. <br> <u>Classification Models spaces preperartion to use in hyperopt :*</u>

# %%
space_xgboost_clf  = {
    'learning_rate': hp.loguniform('learning_rate', -5, 0),
    'n_estimators': hp.quniform('n_estimators', 50, 200, 1),
    'max_depth': hp.choice('max_depth', range(3, 15)),
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
    'gamma': hp.uniform('gamma', 0, 1),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1.0),
}

space_rf_clf = {
    'n_estimators': hp.quniform('n_estimators', 50, 200, 1),
    #'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'max_depth': hp.choice('max_depth', range(3, 15)),
    'min_samples_split': hp.uniform('min_samples_split', 0.1, 1.0),
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.1, 0.5),
    #'max_features': hp.choice('max_features', ['auto', 'sqrt', 'log2', None]),
    'bootstrap': hp.choice('bootstrap', [True, False]),
}


space_GradientBoosting_clf = {
    'n_estimators': hp.quniform('n_estimators', 50, 200, 1),
    'learning_rate': hp.loguniform('learning_rate', -5, 0),
    'max_depth': hp.choice('max_depth', range(3, 15)),
    'min_samples_split': hp.uniform('min_samples_split', 0.1, 1.0),
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.1, 0.5),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
}

space_DT = {
    #'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'splitter': hp.choice('splitter', ['best', 'random']),
    'max_depth': hp.choice('depth', range(1, 15)),
    'min_samples_split': hp.uniform('min_samples_split', 0.1, 1.0),
    'min_samples_leaf': hp.uniform('min_samples_leaf', 0.1, 0.5),
    #'max_features': hp.choice('max_features', ['auto', 'sqrt', 'log2', None]),
}



space_Bagging_clf = {
    'n_estimators': hp.quniform('n_estimators', 10, 200, 1),
    'max_samples': hp.uniform('max_samples', 0.1, 1.0),
    'max_features': hp.uniform('max_features', 0.1, 1.0),
    'bootstrap': hp.choice('bootstrap', [True, False]),
    'bootstrap_features': hp.choice('bootstrap_features', [True, False]),
}

space_catboost_clf = {
    'learning_rate': hp.loguniform('learning_rate', -5, 0),
    'iterations': hp.quniform('iterations', 50, 200, 1),
    'depth': hp.choice('depth', range(1, 15)),
    'l2_leaf_reg': hp.uniform('l2_leaf_reg', 0.1, 10),
    'border_count': hp.choice('border_count', [32, 64, 128, 256]),
    'bagging_temperature': hp.uniform('bagging_temperature', 0, 1),
    'random_strength': hp.uniform('random_strength', 0, 1),
}

# %% [markdown]
# ---

# %% [markdown]
# ### *B. <br> <u>Data preparation:*</u>

# %% [markdown]
# #### *B.1. <br> <u>Solving imbalanced issue if exist :*</u>

# %%
print(df5.groupby("agecat")["agecat"].count())
print(df5.groupby("agecat")["agecat"].count()/df5["agecat"].count())
# Out:
# agecat
# 1     5742
# 2    12875
# 3    15767
# 4    16189
# 5    10736
# 6     6547
# Name: agecat, dtype: int64
# agecat
# 1    0.084620
# 2    0.189740
# 3    0.232360
# 4    0.238579
# 5    0.158217
# 6    0.096484
# Name: agecat, dtype: float64

# %% [markdown]
# > *The data balnance between between veh_age are acceptable*

# %% [markdown]
# #### *B.2. <br> <u>LabelEncoding for categorical features :*</u>

# %%
LabelEncoder_cat = LabelEncoder()
for col in df5:
    if col in ["numclaims","veh_body","veh_age","gender","area","agecat"]:
        df5[col]=LabelEncoder_cat.fit_transform(df5[col])

# %% [markdown]
# #### *B.3. <br> <u>Define x & y features :*</u>

# %%
x=df5.drop("agecat",axis=1)
y=df5["agecat"]

# %% [markdown]
# #### *B.5. <br> <u>data splitting (training & testing) :*</u>

# %%
xtrain,xtest, ytrain, ytest = train_test_split(x, y, train_size=0.7, test_size=0.3,random_state=41)

# %% [markdown]
# ---

# %% [markdown]
# ### *C. <br> <u>Modelling:*</u>

# %% [markdown]
# * *Note : Data scalling is not required as we are applying Tree -based models*

# %% [markdown]
# #### *C.1 <br> <u>* *XGBClassifier:*</u>

# %%
def model_XGBClassifier(space_xgboost_clf):
    accuracyList=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("XGBClassifier",XGBClassifier( 
               learning_rate=float(space_xgboost_clf['learning_rate']),
               n_estimators=int(space_xgboost_clf['n_estimators']),
               max_depth=int(space_xgboost_clf['max_depth']),
               min_child_weight=int(space_xgboost_clf['min_child_weight']),
               subsample=float(space_xgboost_clf["subsample"]),
               gamma=float(space_xgboost_clf['gamma']),
               colsample_bytree=float(space_xgboost_clf['colsample_bytree'])                                      

                                    ))

                                    ])
                                  
    model_opt.fit(xtrain,ytrain)
    Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
    accuracyList.append(Accuracy_result)                         
    mean_Accuracy_result=np.mean(accuracyList)                          
    return { 
           'loss': mean_Accuracy_result,
           'status': STATUS_OK
            }

# %%
def model_XGBClassifier_best(best_model_XGBClassifier):
    y_model_XGBClassifier_best=[]
    Accuracy_list=[]
    model_opt = Pipeline(
        steps=[
           #('preprocessor', preprocessor),
            ("XGBClassifier",XGBClassifier( 
               learning_rate=float(best_model_XGBClassifier['learning_rate']),
               n_estimators=int(best_model_XGBClassifier['n_estimators']),
               max_depth=int(best_model_XGBClassifier['max_depth']),
               min_child_weight=int(best_model_XGBClassifier['min_child_weight']),
               subsample=float(best_model_XGBClassifier["subsample"]),
               gamma=float(best_model_XGBClassifier['gamma']),
               colsample_bytree=float(best_model_XGBClassifier['colsample_bytree'])                                      

                                    ))

                                    ])
                                  
    model_opt.fit(xtrain,ytrain)
    y_pred=model_opt.predict(xtest)
    y_model_XGBClassifier_best.append(y_pred)

    Accuracy_result=accuracy_score(ytest,y_pred)
    Accuracy_list.append(Accuracy_result)
   

    print('model_XGBClassifier_best Accuracy_result:',  np.mean(Accuracy_list))

# %%
best_model_XGBClassifier = fmin(fn=model_XGBClassifier, space=space_xgboost_clf, algo=tpe.suggest, max_evals=10)
# Out:
# 100%|██████████| 10/10 [03:21<00:00, 20.14s/trial, best loss: 0.2220857690229405]

# %%
model_XGBClassifier_best(best_model_XGBClassifier)
# Out:
# model_XGBClassifier_best Accuracy_result: 0.2245910497617527

# %% [markdown]
# ---

# %% [markdown]
# #### *C.2 <br> <u>* *RandomForestClassifier:*</u>

# %%
def model_rf_clf(space_rf_clf):
    accuracyList=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("RandomForestClassifier",RandomForestClassifier(              
                                    n_estimators=int(space_rf_clf['n_estimators']),
                                    #criterion=int(space_rf_clf['criterion']),                                                       
                                    max_depth=int(space_rf_clf['max_depth']),
                                    min_samples_split=float(space_rf_clf['min_samples_split']),
                                    min_samples_leaf=float(space_rf_clf['min_samples_leaf']),
                                    #max_features=float(space_rf_clf["max_features"]),
                                    bootstrap=int(space_rf_clf['bootstrap'])

                                    ))

                                    ])

                                  
    model_opt.fit(xtrain,ytrain)
    Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
    accuracyList.append(Accuracy_result)                         
    mean_Accuracy_result=np.mean(accuracyList)                          
    return { 
           'loss': mean_Accuracy_result,
           'status': STATUS_OK
            }

# %%
def model_rf_clf_best(best_model_rf_clf):
    y_model_rf_clf_best=[]
    Accuracy_list=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
              ("RandomForestClassifier",RandomForestClassifier(              
                                    n_estimators=int(best_model_rf_clf['n_estimators']),
                                    #criterion=int(best_model_rf_clf['criterion']),                                                       
                                    max_depth=int(best_model_rf_clf['max_depth']),
                                    min_samples_split=float(best_model_rf_clf['min_samples_split']),
                                    min_samples_leaf=float(best_model_rf_clf['min_samples_leaf']),
                                    #max_features=float(space_rf_clf["max_features"]),
                                    bootstrap=int(best_model_rf_clf['bootstrap'])

                                    ))

                                    ])

                                  
    model_opt.fit(xtrain,ytrain)
    y_pred=model_opt.predict(xtest)
    y_model_rf_clf_best.append(y_pred)

    Accuracy_result=accuracy_score(ytest,y_pred)
    Accuracy_list.append(Accuracy_result)
   

    print('model_rf_clf_best Accuracy_result:',  np.mean(Accuracy_list))

# %%
best_model_rf_clf = fmin(fn=model_rf_clf, space=space_rf_clf, algo=tpe.suggest, max_evals=10)
model_rf_clf_best(best_model_rf_clf)
# Out:
#  10%|█         | 1/10 [00:01<00:13,  1.49s/trial, best loss: 0.2563737289384487]
# 100%|██████████| 10/10 [00:11<00:00,  1.16s/trial, best loss: 0.23809991649064205]
# model_rf_clf_best Accuracy_result: 0.2448789114309574

# %% [markdown]
# ---

# %% [markdown]
# #### *C.3 <br> <u>* *GradientBoostingClassifier:*</u>

# %%
def model_GradientBoosting_clf(space_GradientBoosting_clf):
    accuracyList=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("GradientBoostingClassifier",GradientBoostingClassifier(              
                                    n_estimators=int(space_GradientBoosting_clf['n_estimators']),                                                       
                                    learning_rate=float(space_GradientBoosting_clf['learning_rate']),
                                    max_depth=int(space_GradientBoosting_clf['max_depth']),
                                    min_samples_split=float(space_GradientBoosting_clf['min_samples_split']),
                                    min_samples_leaf=float(space_GradientBoosting_clf['min_samples_leaf']),
                                    subsample=float(space_GradientBoosting_clf['subsample'])

                                    ))

                                    ])
                                  
    model_opt.fit(xtrain,ytrain)
    Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
    accuracyList.append(Accuracy_result)                         
    mean_Accuracy_result=np.mean(accuracyList)                          
    return { 
           'loss': mean_Accuracy_result,
           'status': STATUS_OK
            }

# %%
def model_GradientBoosting_clf_best(best_model_GradientBoosting_clf):
    y_DT_best=[]
    Accuracy_list=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("GradientBoostingClassifier",GradientBoostingClassifier(              
                                    n_estimators=int(best_model_GradientBoosting_clf['n_estimators']),                                                       
                                    learning_rate=float(best_model_GradientBoosting_clf['learning_rate']),
                                    max_depth=int(best_model_GradientBoosting_clf['max_depth']),
                                    min_samples_split=float(best_model_GradientBoosting_clf['min_samples_split']),
                                    min_samples_leaf=float(best_model_GradientBoosting_clf['min_samples_leaf']),
                                    subsample=float(best_model_GradientBoosting_clf['subsample'])


                                    ))

                                    ])

                                  
    model_opt.fit(xtrain,ytrain)
    y_pred=model_opt.predict(xtest)
    y_DT_best.append(y_pred)

    Accuracy_result=accuracy_score(ytest,y_pred)
    Accuracy_list.append(Accuracy_result)
   

    print('model_GradientBoosting_clf_best Accuracy_result:',  np.mean(Accuracy_list))

# %%
best_model_GradientBoosting_clf = fmin(fn=model_GradientBoosting_clf, space=space_GradientBoosting_clf, algo=tpe.suggest, max_evals=10)
model_GradientBoosting_clf_best(best_model_GradientBoosting_clf)
# Out:
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 10/10 [03:21<00:00, 20.16s/trial, best loss: 0.23809991649064205]
# model_GradientBoosting_clf_best Accuracy_result: 0.23809991649064205

# %% [markdown]
# ----

# %% [markdown]
# #### *C.4 <br> <u>* *DecisionTreeClassifier:*</u>

# %%
def model_DT(space_DT):
    accuracyList=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("BaggingClassifier",DecisionTreeClassifier(              
                                    #criterion=int(space_DT['criterion']),                                                       
                                    splitter=str(space_DT['splitter']),
                                    max_depth=int(space_DT['max_depth']),
                                    min_samples_split=float(space_DT['min_samples_split']),
                                    min_samples_leaf=float(space_DT['min_samples_leaf']),
                                    #max_features=int(space_DT['max_features'])

                                    ))

                                    ])

                                  
    model_opt.fit(xtrain,ytrain)
    Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
    accuracyList.append(Accuracy_result)                         
    mean_Accuracy_result=np.mean(accuracyList)                          
    return { 
           'loss': mean_Accuracy_result,
           'status': STATUS_OK
            }

# %%
def model_DT_best(best_model_DT):
    y_DT_best=[]
    Accuracy_list=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("BaggingClassifier",DecisionTreeClassifier(              
                                    #criterion=int(best_model_DT['criterion']),                                                       
                                    #splitter=str(best_model_DT['splitter']),
                                    max_depth=int(best_model_DT['depth']),
                                    min_samples_split=float(best_model_DT['min_samples_split']),
                                    min_samples_leaf=float(best_model_DT['min_samples_leaf']),
                                    #max_features=int(best_model_DT['max_features'])

                                    ))

                                    ])

                                  
    model_opt.fit(xtrain,ytrain)
    y_pred=model_opt.predict(xtest)
    y_DT_best.append(y_pred)

    Accuracy_result=accuracy_score(ytest,y_pred)
    Accuracy_list.append(Accuracy_result)
   

    print('model_DT_best Accuracy_result:',  np.mean(Accuracy_list))

# %%
best_model_DT = fmin(fn=model_DT, space=space_DT, algo=tpe.suggest, max_evals=10)
model_DT_best(best_model_DT)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 38.49trial/s, best loss: 0.23063319742594685]
# model_DT_best Accuracy_result: 0.244829788279216

# %% [markdown]
# ---

# %% [markdown]
# #### *C.5 <br> <u>* *BaggingClassifier:*</u>

# %%
def model_Bagging(space_Bagging_clf):
    base_classifier =DecisionTreeClassifier()
    accuracyList=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("BaggingClassifier",BaggingClassifier(base_estimator=base_classifier,                
                                    n_estimators=int(space_Bagging_clf['n_estimators']),
                                    bootstrap=int(space_Bagging_clf["bootstrap"]),                                                       
                                    bootstrap_features=int(space_Bagging_clf['bootstrap_features']),
                                    max_samples=float(space_Bagging_clf["max_samples"]),
                                    max_features=float(space_Bagging_clf["max_features"])

                                    ))

                                    ])
                                              
                                  
    model_opt.fit(xtrain,ytrain)
    Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
    accuracyList.append(Accuracy_result)                         
    mean_Accuracy_result=np.mean(accuracyList)                          
    return { 
           'loss': mean_Accuracy_result,
           'status': STATUS_OK
            }

# %%
def model_Bagging_best(best_model_BaggingClassifier):
    base_classifier =DecisionTreeClassifier()
    y_Bagging_best=[]
    Accuracy_list=[]

    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("CatBoostRegressor",BaggingClassifier(base_estimator=base_classifier,                
                                    n_estimators=int(best_model_BaggingClassifier['n_estimators']),
                                    bootstrap=int(best_model_BaggingClassifier["bootstrap"]),                                                       
                                    bootstrap_features=int(best_model_BaggingClassifier['bootstrap_features']),
                                    max_samples=float(best_model_BaggingClassifier["max_samples"]),
                                    max_features=float(best_model_BaggingClassifier["max_features"])

                                    ))

                                    ])
                                              
                                  
    model_opt.fit(xtrain,ytrain)
    y_pred=model_opt.predict(xtest)
    y_Bagging_best.append(y_pred)

    Accuracy_result=accuracy_score(ytest,y_pred)
    Accuracy_list.append(Accuracy_result)
   

    print('model_Bagging_best Accuracy_result:',  np.mean(Accuracy_list))

# %%
best_model_BaggingClassifier=fmin(fn=model_Bagging, space=space_Bagging_clf, algo=tpe.suggest, max_evals=10)
model_Bagging_best(best_model_BaggingClassifier)
# Out:
# 100%|██████████| 10/10 [03:30<00:00, 21.08s/trial, best loss: 0.2120646460676917]
# model_Bagging_best Accuracy_result: 0.2230191089060274

# %% [markdown]
# ---

# %% [markdown]
# #### *C.6 <br> <u>* *CatBoostClassifier:*</u>

# %%
def model_catboost(space_catboost_clf):
    accuracyList=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("CatBoostRegressor",CatBoostClassifier(
                                    learning_rate=float(space_catboost_clf['learning_rate']),
                                    depth=int(space_catboost_clf["depth"]),                                                       
                                    iterations=int(space_catboost_clf['iterations']),
                                    l2_leaf_reg=float(space_catboost_clf["l2_leaf_reg"]),
                                    border_count=int(space_catboost_clf["border_count"]),
                                    bagging_temperature=float(space_catboost_clf["bagging_temperature"]),
                                    random_strength=float(space_catboost_clf["random_strength"])

                                    ))

                                    ])
                                              
                                  
    model_opt.fit(xtrain,ytrain)
    Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
    accuracyList.append(Accuracy_result)                         
    mean_Accuracy_result=np.mean(accuracyList)                          
    return { 
           'loss': mean_Accuracy_result,
           'status': STATUS_OK
            }

# %%
def model_catboost_best(best_model_catboost):
    y_CatBoostClassifier_best=[]
    model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
            ("CatBoostRegressor",CatBoostClassifier(
                                    learning_rate=float(best_model_catboost['learning_rate']),
                                    depth=int(best_model_catboost["depth"]),                                                       
                                    iterations=int(best_model_catboost['iterations']),
                                    l2_leaf_reg=float(best_model_catboost["l2_leaf_reg"]),
                                    border_count=int(best_model_catboost["border_count"]),
                                    bagging_temperature=float(best_model_catboost["bagging_temperature"]),
                                    random_strength=float(best_model_catboost["random_strength"])

                                    ))

                                    ])
                                              
                                  
    model_opt.fit(xtrain,ytrain)
    y_pred=model_opt.predict(xtest)
    y_CatBoostClassifier_best.append(y_pred)

    Accuracy_result=accuracy_score(ytest,y_pred)
    print('model_catboost_best Accuracy_result:', Accuracy_result)

# %%
best_model_catboost = fmin(fn=model_catboost, space=space_catboost_clf, algo=tpe.suggest, max_evals=10)
model_catboost_best(best_model_catboost)
# Out:
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]0:	learn: 1.7039020	total: 157ms	remaining: 23.7s
# 1:	learn: 1.6953394	total: 175ms	remaining: 13.1s
# 2:	learn: 1.6921836	total: 194ms	remaining: 9.62s
# 3:	learn: 1.6873795	total: 214ms	remaining: 7.93s
# 4:	learn: 1.6839783	total: 233ms	remaining: 6.86s
# 5:	learn: 1.6825117	total: 251ms	remaining: 6.11s
# 6:	learn: 1.6798326	total: 270ms	remaining: 5.58s
# 7:	learn: 1.6790050	total: 286ms	remaining: 5.14s
# 8:	learn: 1.6761882	total: 309ms	remaining: 4.91s
# 9:	learn: 1.6737101	total: 328ms	remaining: 4.65s
# 10:	learn: 1.6727076	total: 345ms	remaining: 4.42s
# 11:	learn: 1.6709197	total: 364ms	remaining: 4.25s
# 12:	learn: 1.6692301	total: 381ms	remaining: 4.08s
# 13:	learn: 1.6678631	total: 403ms	remaining: 3.97s
# 14:	learn: 1.6670424	total: 421ms	remaining: 3.85s
# 15:	learn: 1.6649770	total: 441ms	remaining: 3.75s
# 16:	learn: 1.6639760	total: 460ms	remaining: 3.65s
# 17:	learn: 1.6636666	total: 477ms	remaining: 3.55s
# 18:	learn: 1.6623524	total: 494ms	remaining: 3.46s
# 19:	learn: 1.6610154	total: 513ms	remaining: 3.39s
# 20:	learn: 1.6601566	total: 531ms	remaining: 3.31s
# 21:	learn: 1.6586745	total: 556ms	remaining: 3.28s
# 22:	learn: 1.6577519	total: 577ms	remaining: 3.24s
# 23:	learn: 1.6569646	total: 596ms	remaining: 3.18s
# 24:	learn: 1.6566088	total: 613ms	remaining: 3.12s
# 25:	learn: 1.6549263	total: 634ms	remaining: 3.07s
# 26:	learn: 1.6538579	total: 653ms	remaining: 3.02s
# 27:	learn: 1.6530943	total: 670ms	remaining: 2.97s
# 28:	learn: 1.6514150	total: 690ms	remaining: 2.93s
# 29:	learn: 1.6501881	total: 709ms	remaining: 2.88s
# 30:	learn: 1.6491903	total: 728ms	remaining: 2.84s
# 31:	learn: 1.6480689	total: 747ms	remaining: 2.8s
# 32:	learn: 1.6473038	total: 765ms	remaining: 2.76s
# 33:	learn: 1.6463319	total: 784ms	remaining: 2.72s
# 34:	learn: 1.6450475	total: 805ms	remaining: 2.69s
# 35:	learn: 1.6442674	total: 822ms	remaining: 2.65s
# 36:	learn: 1.6436459	total: 841ms	remaining: 2.61s
# 37:	learn: 1.6421875	total: 859ms	remaining: 2.58s
# 38:	learn: 1.6415436	total: 877ms	remaining: 2.54s
# 39:	learn: 1.6409259	total: 894ms	remaining: 2.5s
# 40:	learn: 1.6404057	total: 910ms	remaining: 2.46s
# 41:	learn: 1.6395386	total: 928ms	remaining: 2.43s
# 42:	learn: 1.6384372	total: 949ms	remaining: 2.4s
# 43:	learn: 1.6375881	total: 975ms	remaining: 2.39s
# 44:	learn: 1.6366065	total: 1s	remaining: 2.39s
# 45:	learn: 1.6361300	total: 1.03s	remaining: 2.37s
# 46:	learn: 1.6350265	total: 1.05s	remaining: 2.35s
# 47:	learn: 1.6343948	total: 1.07s	remaining: 2.31s
# 48:	learn: 1.6332919	total: 1.09s	remaining: 2.29s
# 49:	learn: 1.6325163	total: 1.11s	remaining: 2.26s
# 50:	learn: 1.6316839	total: 1.13s	remaining: 2.23s
# 51:	learn: 1.6310063	total: 1.15s	remaining: 2.2s
# 52:	learn: 1.6299847	total: 1.16s	remaining: 2.17s
# 53:	learn: 1.6294014	total: 1.18s	remaining: 2.14s
# 54:	learn: 1.6290350	total: 1.2s	remaining: 2.11s
# 55:	learn: 1.6281493	total: 1.22s	remaining: 2.09s
# 56:	learn: 1.6272564	total: 1.24s	remaining: 2.06s
# 57:	learn: 1.6263663	total: 1.26s	remaining: 2.04s
# 58:	learn: 1.6255293	total: 1.27s	remaining: 2.01s
# 59:	learn: 1.6249687	total: 1.29s	remaining: 1.98s
# 60:	learn: 1.6239238	total: 1.31s	remaining: 1.96s
# 61:	learn: 1.6229263	total: 1.33s	remaining: 1.94s
# 62:	learn: 1.6222854	total: 1.35s	remaining: 1.91s
# 63:	learn: 1.6217643	total: 1.37s	remaining: 1.88s
# 64:	learn: 1.6209290	total: 1.39s	remaining: 1.86s
# 65:	learn: 1.6205108	total: 1.41s	remaining: 1.84s
# 66:	learn: 1.6201036	total: 1.43s	remaining: 1.81s
# 67:	learn: 1.6195079	total: 1.45s	remaining: 1.79s
# 68:	learn: 1.6185805	total: 1.47s	remaining: 1.76s
# 69:	learn: 1.6179680	total: 1.49s	remaining: 1.74s
# 70:	learn: 1.6173263	total: 1.51s	remaining: 1.72s
# 71:	learn: 1.6160916	total: 1.53s	remaining: 1.7s
# 72:	learn: 1.6153623	total: 1.55s	remaining: 1.67s
# 73:	learn: 1.6148123	total: 1.56s	remaining: 1.65s
# 74:	learn: 1.6140849	total: 1.58s	remaining: 1.63s
# 75:	learn: 1.6128675	total: 1.6s	remaining: 1.6s
# 76:	learn: 1.6125836	total: 1.62s	remaining: 1.58s
# 77:	learn: 1.6121020	total: 1.64s	remaining: 1.56s
# 78:	learn: 1.6111174	total: 1.66s	remaining: 1.54s
# 79:	learn: 1.6108126	total: 1.68s	remaining: 1.51s
# 80:	learn: 1.6104866	total: 1.7s	remaining: 1.49s
# 81:	learn: 1.6097074	total: 1.71s	remaining: 1.46s
# 82:	learn: 1.6092220	total: 1.73s	remaining: 1.44s
# 83:	learn: 1.6083458	total: 1.75s	remaining: 1.42s
# 84:	learn: 1.6077713	total: 1.77s	remaining: 1.4s
# 85:	learn: 1.6066149	total: 1.79s	remaining: 1.38s
# 86:	learn: 1.6058730	total: 1.81s	remaining: 1.35s
# 87:	learn: 1.6053536	total: 1.83s	remaining: 1.33s
# 88:	learn: 1.6048342	total: 1.85s	remaining: 1.31s
# 89:	learn: 1.6042923	total: 1.87s	remaining: 1.29s
# 90:	learn: 1.6037697	total: 1.89s	remaining: 1.27s
# 91:	learn: 1.6029869	total: 1.91s	remaining: 1.24s
# 92:	learn: 1.6022066	total: 1.93s	remaining: 1.22s
# 93:	learn: 1.6015117	total: 1.94s	remaining: 1.2s
# 94:	learn: 1.6008738	total: 1.96s	remaining: 1.18s
# 95:	learn: 1.6001215	total: 1.98s	remaining: 1.16s
# 96:	learn: 1.5995880	total: 2s	remaining: 1.13s
# 97:	learn: 1.5988020	total: 2.02s	remaining: 1.11s
# 98:	learn: 1.5981412	total: 2.03s	remaining: 1.09s
# 99:	learn: 1.5975273	total: 2.05s	remaining: 1.07s
# 100:	learn: 1.5966647	total: 2.07s	remaining: 1.05s
# 101:	learn: 1.5959504	total: 2.09s	remaining: 1.03s
# 102:	learn: 1.5952180	total: 2.11s	remaining: 1s
# 103:	learn: 1.5946273	total: 2.13s	remaining: 986ms
# 104:	learn: 1.5935269	total: 2.16s	remaining: 966ms
# 105:	learn: 1.5933084	total: 2.18s	remaining: 944ms
# 106:	learn: 1.5928636	total: 2.19s	remaining: 922ms
# 107:	learn: 1.5918126	total: 2.21s	remaining: 903ms
# 108:	learn: 1.5912697	total: 2.23s	remaining: 881ms
# 109:	learn: 1.5902988	total: 2.26s	remaining: 862ms
# 110:	learn: 1.5894571	total: 2.28s	remaining: 842ms
# 111:	learn: 1.5888895	total: 2.3s	remaining: 821ms
# 112:	learn: 1.5886075	total: 2.31s	remaining: 799ms
# 113:	learn: 1.5877836	total: 2.33s	remaining: 778ms
# 114:	learn: 1.5870657	total: 2.35s	remaining: 757ms
# 115:	learn: 1.5863300	total: 2.37s	remaining: 737ms
# 116:	learn: 1.5854660	total: 2.39s	remaining: 716ms
# 117:	learn: 1.5846641	total: 2.41s	remaining: 695ms
# 118:	learn: 1.5841902	total: 2.43s	remaining: 675ms
# 119:	learn: 1.5832485	total: 2.45s	remaining: 654ms
# 120:	learn: 1.5829479	total: 2.47s	remaining: 633ms
# 121:	learn: 1.5825746	total: 2.49s	remaining: 612ms
# 122:	learn: 1.5817906	total: 2.51s	remaining: 592ms
# 123:	learn: 1.5814706	total: 2.53s	remaining: 571ms
# 124:	learn: 1.5811616	total: 2.54s	remaining: 550ms
# 125:	learn: 1.5805548	total: 2.56s	remaining: 529ms
# 126:	learn: 1.5799366	total: 2.58s	remaining: 509ms
# 127:	learn: 1.5790404	total: 2.6s	remaining: 489ms
# 128:	learn: 1.5786512	total: 2.63s	remaining: 468ms
# 129:	learn: 1.5782668	total: 2.64s	remaining: 447ms
# 130:	learn: 1.5775297	total: 2.67s	remaining: 429ms
# 131:	learn: 1.5769994	total: 2.71s	remaining: 410ms
# 132:	learn: 1.5763231	total: 2.74s	remaining: 392ms
# 133:	learn: 1.5760572	total: 2.77s	remaining: 372ms
# 134:	learn: 1.5754944	total: 2.81s	remaining: 353ms
# 135:	learn: 1.5748300	total: 2.84s	remaining: 334ms
# 136:	learn: 1.5743422	total: 2.87s	remaining: 314ms
# 137:	learn: 1.5739435	total: 2.9s	remaining: 294ms
# 138:	learn: 1.5731932	total: 2.93s	remaining: 274ms
# 139:	learn: 1.5721519	total: 2.96s	remaining: 254ms
# 140:	learn: 1.5715055	total: 3s	remaining: 234ms
# 141:	learn: 1.5708679	total: 3.03s	remaining: 213ms
# 142:	learn: 1.5704431	total: 3.06s	remaining: 193ms
# 143:	learn: 1.5697603	total: 3.09s	remaining: 172ms
# 144:	learn: 1.5693930	total: 3.12s	remaining: 151ms
# 145:	learn: 1.5688344	total: 3.15s	remaining: 130ms
# 146:	learn: 1.5683447	total: 3.18s	remaining: 108ms
# 147:	learn: 1.5681304	total: 3.21s	remaining: 86.8ms
# 148:	learn: 1.5675891	total: 3.24s	remaining: 65.2ms
# 149:	learn: 1.5672540	total: 3.27s	remaining: 43.6ms
# 150:	learn: 1.5667335	total: 3.3s	remaining: 21.9ms
# 151:	learn: 1.5660761	total: 3.34s	remaining: 0us
#  10%|█         | 1/10 [00:03<00:31,  3.47s/trial, best loss: 0.24438767991354327]0:	learn: 1.7905989	total: 22.6ms	remaining: 1.47s
# 1:	learn: 1.7894562	total: 41.3ms	remaining: 1.32s
# 2:	learn: 1.7883312	total: 61.3ms	remaining: 1.29s
# 3:	learn: 1.7872961	total: 80.9ms	remaining: 1.25s
# 4:	learn: 1.7862040	total: 99.5ms	remaining: 1.21s
# 5:	learn: 1.7851286	total: 118ms	remaining: 1.18s
# 6:	learn: 1.7840697	total: 138ms	remaining: 1.16s
# 7:	learn: 1.7830269	total: 156ms	remaining: 1.13s
# 8:	learn: 1.7820001	total: 175ms	remaining: 1.11s
# 9:	learn: 1.7809889	total: 194ms	remaining: 1.09s
# 10:	learn: 1.7799931	total: 214ms	remaining: 1.07s
# 11:	learn: 1.7790124	total: 233ms	remaining: 1.05s
# 12:	learn: 1.7780832	total: 253ms	remaining: 1.03s
# 13:	learn: 1.7771958	total: 272ms	remaining: 1.01s
# 14:	learn: 1.7762562	total: 291ms	remaining: 989ms
# 15:	learn: 1.7753666	total: 309ms	remaining: 965ms
# 16:	learn: 1.7744537	total: 328ms	remaining: 945ms
# 17:	learn: 1.7735545	total: 346ms	remaining: 924ms
# 18:	learn: 1.7726688	total: 366ms	remaining: 906ms
# 19:	learn: 1.7718290	total: 387ms	remaining: 890ms
# 20:	learn: 1.7709683	total: 407ms	remaining: 872ms
# 21:	learn: 1.7701205	total: 428ms	remaining: 855ms
# 22:	learn: 1.7693161	total: 448ms	remaining: 838ms
# 23:	learn: 1.7684922	total: 469ms	remaining: 821ms
# 24:	learn: 1.7676806	total: 488ms	remaining: 800ms
# 25:	learn: 1.7669101	total: 514ms	remaining: 791ms
# 26:	learn: 1.7661212	total: 538ms	remaining: 776ms
# 27:	learn: 1.7653440	total: 562ms	remaining: 763ms
# 28:	learn: 1.7646660	total: 585ms	remaining: 746ms
# 29:	learn: 1.7639103	total: 607ms	remaining: 728ms
# 30:	learn: 1.7631659	total: 626ms	remaining: 707ms
# 31:	learn: 1.7624324	total: 647ms	remaining: 688ms
# 32:	learn: 1.7617098	total: 668ms	remaining: 668ms
# 33:	learn: 1.7609979	total: 688ms	remaining: 648ms
# 34:	learn: 1.7603183	total: 708ms	remaining: 627ms
# 35:	learn: 1.7596488	total: 726ms	remaining: 605ms
# 36:	learn: 1.7590146	total: 745ms	remaining: 584ms
# 37:	learn: 1.7584008	total: 764ms	remaining: 563ms
# 38:	learn: 1.7577587	total: 782ms	remaining: 541ms
# 39:	learn: 1.7571022	total: 801ms	remaining: 520ms
# 40:	learn: 1.7564783	total: 819ms	remaining: 499ms
# 41:	learn: 1.7558398	total: 839ms	remaining: 479ms
# 42:	learn: 1.7552107	total: 858ms	remaining: 459ms
# 43:	learn: 1.7546406	total: 878ms	remaining: 439ms
# 44:	learn: 1.7540503	total: 897ms	remaining: 419ms
# 45:	learn: 1.7534461	total: 916ms	remaining: 398ms
# 46:	learn: 1.7528724	total: 934ms	remaining: 378ms
# 47:	learn: 1.7522847	total: 953ms	remaining: 357ms
# 48:	learn: 1.7517269	total: 972ms	remaining: 337ms
# 49:	learn: 1.7511553	total: 990ms	remaining: 317ms
# 50:	learn: 1.7506645	total: 1.01s	remaining: 298ms
# 51:	learn: 1.7501546	total: 1.03s	remaining: 277ms
# 52:	learn: 1.7496265	total: 1.05s	remaining: 257ms
# 53:	learn: 1.7491062	total: 1.07s	remaining: 237ms
# 54:	learn: 1.7485708	total: 1.09s	remaining: 217ms
# 55:	learn: 1.7480431	total: 1.11s	remaining: 198ms
# 56:	learn: 1.7475232	total: 1.13s	remaining: 178ms
# 57:	learn: 1.7470307	total: 1.14s	remaining: 158ms
# 58:	learn: 1.7465248	total: 1.16s	remaining: 138ms
# 59:	learn: 1.7460459	total: 1.18s	remaining: 118ms
# 60:	learn: 1.7455537	total: 1.2s	remaining: 98.4ms
# 61:	learn: 1.7451043	total: 1.22s	remaining: 78.7ms
# 62:	learn: 1.7446255	total: 1.24s	remaining: 59ms
# 63:	learn: 1.7441888	total: 1.26s	remaining: 39.3ms
# 64:	learn: 1.7437229	total: 1.27s	remaining: 19.6ms
# 65:	learn: 1.7432638	total: 1.29s	remaining: 0us
#  20%|██        | 2/10 [00:04<00:18,  2.27s/trial, best loss: 0.24438767991354327]0:	learn: 1.7414226	total: 36.4ms	remaining: 5.36s
# 1:	learn: 1.7192509	total: 67.6ms	remaining: 4.93s
# 2:	learn: 1.7085300	total: 93.6ms	remaining: 4.52s
# 3:	learn: 1.7006641	total: 122ms	remaining: 4.38s
# 4:	learn: 1.6970234	total: 153ms	remaining: 4.39s
# 5:	learn: 1.6932445	total: 187ms	remaining: 4.43s
# 6:	learn: 1.6909824	total: 216ms	remaining: 4.35s
# 7:	learn: 1.6888178	total: 244ms	remaining: 4.26s
# 8:	learn: 1.6872210	total: 273ms	remaining: 4.21s
# 9:	learn: 1.6853210	total: 304ms	remaining: 4.19s
# 10:	learn: 1.6839098	total: 336ms	remaining: 4.18s
# 11:	learn: 1.6831057	total: 365ms	remaining: 4.14s
# 12:	learn: 1.6824503	total: 395ms	remaining: 4.1s
# 13:	learn: 1.6818253	total: 424ms	remaining: 4.06s
# 14:	learn: 1.6812789	total: 457ms	remaining: 4.05s
# 15:	learn: 1.6805062	total: 487ms	remaining: 4.02s
# 16:	learn: 1.6796806	total: 512ms	remaining: 3.94s
# 17:	learn: 1.6790787	total: 539ms	remaining: 3.89s
# 18:	learn: 1.6783887	total: 569ms	remaining: 3.86s
# 19:	learn: 1.6777583	total: 596ms	remaining: 3.81s
# 20:	learn: 1.6772538	total: 623ms	remaining: 3.77s
# 21:	learn: 1.6767958	total: 650ms	remaining: 3.73s
# 22:	learn: 1.6763900	total: 678ms	remaining: 3.68s
# 23:	learn: 1.6760076	total: 707ms	remaining: 3.65s
# 24:	learn: 1.6753450	total: 736ms	remaining: 3.62s
# 25:	learn: 1.6745134	total: 768ms	remaining: 3.6s
# 26:	learn: 1.6738436	total: 803ms	remaining: 3.6s
# 27:	learn: 1.6731543	total: 834ms	remaining: 3.58s
# 28:	learn: 1.6728006	total: 863ms	remaining: 3.54s
# 29:	learn: 1.6724135	total: 891ms	remaining: 3.5s
# 30:	learn: 1.6722208	total: 916ms	remaining: 3.46s
# 31:	learn: 1.6716900	total: 942ms	remaining: 3.41s
# 32:	learn: 1.6709241	total: 970ms	remaining: 3.38s
# 33:	learn: 1.6705238	total: 996ms	remaining: 3.34s
# 34:	learn: 1.6700262	total: 1.02s	remaining: 3.31s
# 35:	learn: 1.6695367	total: 1.05s	remaining: 3.28s
# 36:	learn: 1.6691284	total: 1.08s	remaining: 3.25s
# 37:	learn: 1.6687422	total: 1.11s	remaining: 3.21s
# 38:	learn: 1.6684473	total: 1.14s	remaining: 3.18s
# 39:	learn: 1.6682879	total: 1.16s	remaining: 3.14s
# 40:	learn: 1.6679856	total: 1.19s	remaining: 3.1s
# 41:	learn: 1.6675364	total: 1.21s	remaining: 3.07s
# 42:	learn: 1.6673415	total: 1.24s	remaining: 3.03s
# 43:	learn: 1.6670621	total: 1.27s	remaining: 2.99s
# 44:	learn: 1.6668709	total: 1.29s	remaining: 2.95s
# 45:	learn: 1.6667373	total: 1.32s	remaining: 2.92s
# 46:	learn: 1.6664363	total: 1.34s	remaining: 2.88s
# 47:	learn: 1.6660400	total: 1.37s	remaining: 2.85s
# 48:	learn: 1.6654978	total: 1.4s	remaining: 2.83s
# 49:	learn: 1.6650899	total: 1.43s	remaining: 2.81s
# 50:	learn: 1.6648850	total: 1.46s	remaining: 2.77s
# 51:	learn: 1.6644276	total: 1.48s	remaining: 2.74s
# 52:	learn: 1.6642450	total: 1.51s	remaining: 2.71s
# 53:	learn: 1.6640362	total: 1.54s	remaining: 2.68s
# 54:	learn: 1.6637859	total: 1.56s	remaining: 2.65s
# 55:	learn: 1.6632092	total: 1.59s	remaining: 2.62s
# 56:	learn: 1.6629644	total: 1.62s	remaining: 2.59s
# 57:	learn: 1.6623819	total: 1.65s	remaining: 2.56s
# 58:	learn: 1.6621712	total: 1.68s	remaining: 2.53s
# 59:	learn: 1.6619497	total: 1.71s	remaining: 2.5s
# 60:	learn: 1.6616477	total: 1.74s	remaining: 2.47s
# 61:	learn: 1.6612334	total: 1.76s	remaining: 2.45s
# 62:	learn: 1.6610627	total: 1.79s	remaining: 2.42s
# 63:	learn: 1.6607599	total: 1.82s	remaining: 2.39s
# 64:	learn: 1.6605872	total: 1.84s	remaining: 2.36s
# 65:	learn: 1.6602788	total: 1.87s	remaining: 2.33s
# 66:	learn: 1.6598819	total: 1.9s	remaining: 2.3s
# 67:	learn: 1.6593613	total: 1.93s	remaining: 2.27s
# 68:	learn: 1.6589981	total: 1.96s	remaining: 2.24s
# 69:	learn: 1.6586764	total: 1.99s	remaining: 2.21s
# 70:	learn: 1.6584631	total: 2.01s	remaining: 2.18s
# 71:	learn: 1.6581789	total: 2.04s	remaining: 2.15s
# 72:	learn: 1.6577947	total: 2.07s	remaining: 2.13s
# 73:	learn: 1.6575335	total: 2.1s	remaining: 2.1s
# 74:	learn: 1.6571493	total: 2.13s	remaining: 2.07s
# 75:	learn: 1.6568248	total: 2.16s	remaining: 2.04s
# 76:	learn: 1.6565498	total: 2.19s	remaining: 2.02s
# 77:	learn: 1.6562877	total: 2.22s	remaining: 1.99s
# 78:	learn: 1.6560123	total: 2.25s	remaining: 1.96s
# 79:	learn: 1.6557380	total: 2.28s	remaining: 1.94s
# 80:	learn: 1.6555868	total: 2.31s	remaining: 1.91s
# 81:	learn: 1.6550960	total: 2.34s	remaining: 1.89s
# 82:	learn: 1.6549145	total: 2.37s	remaining: 1.85s
# 83:	learn: 1.6545530	total: 2.4s	remaining: 1.83s
# 84:	learn: 1.6542968	total: 2.42s	remaining: 1.8s
# 85:	learn: 1.6540742	total: 2.45s	remaining: 1.77s
# 86:	learn: 1.6538557	total: 2.48s	remaining: 1.74s
# 87:	learn: 1.6537217	total: 2.51s	remaining: 1.71s
# 88:	learn: 1.6533633	total: 2.54s	remaining: 1.68s
# 89:	learn: 1.6532392	total: 2.56s	remaining: 1.65s
# 90:	learn: 1.6527523	total: 2.59s	remaining: 1.62s
# 91:	learn: 1.6525627	total: 2.62s	remaining: 1.6s
# 92:	learn: 1.6522414	total: 2.65s	remaining: 1.57s
# 93:	learn: 1.6519620	total: 2.68s	remaining: 1.54s
# 94:	learn: 1.6514935	total: 2.71s	remaining: 1.51s
# 95:	learn: 1.6510886	total: 2.76s	remaining: 1.49s
# 96:	learn: 1.6508837	total: 2.79s	remaining: 1.47s
# 97:	learn: 1.6505113	total: 2.82s	remaining: 1.44s
# 98:	learn: 1.6502552	total: 2.85s	remaining: 1.41s
# 99:	learn: 1.6501585	total: 2.87s	remaining: 1.38s
# 100:	learn: 1.6498647	total: 3s	remaining: 1.39s
# 101:	learn: 1.6496685	total: 3.11s	remaining: 1.4s
# 102:	learn: 1.6493562	total: 3.22s	remaining: 1.41s
# 103:	learn: 1.6488356	total: 3.31s	remaining: 1.4s
# 104:	learn: 1.6484951	total: 3.33s	remaining: 1.36s
# 105:	learn: 1.6483608	total: 3.35s	remaining: 1.33s
# 106:	learn: 1.6481604	total: 3.37s	remaining: 1.29s
# 107:	learn: 1.6479170	total: 3.39s	remaining: 1.25s
# 108:	learn: 1.6477239	total: 3.41s	remaining: 1.22s
# 109:	learn: 1.6474940	total: 3.42s	remaining: 1.18s
# 110:	learn: 1.6472219	total: 3.44s	remaining: 1.15s
# 111:	learn: 1.6469158	total: 3.45s	remaining: 1.11s
# 112:	learn: 1.6467733	total: 3.47s	remaining: 1.07s
# 113:	learn: 1.6464681	total: 3.49s	remaining: 1.04s
# 114:	learn: 1.6463579	total: 3.5s	remaining: 1s
# 115:	learn: 1.6459375	total: 3.52s	remaining: 971ms
# 116:	learn: 1.6457108	total: 3.54s	remaining: 937ms
# 117:	learn: 1.6453703	total: 3.56s	remaining: 905ms
# 118:	learn: 1.6449592	total: 3.58s	remaining: 873ms
# 119:	learn: 1.6447200	total: 3.6s	remaining: 841ms
# 120:	learn: 1.6445347	total: 3.62s	remaining: 808ms
# 121:	learn: 1.6440845	total: 3.65s	remaining: 777ms
# 122:	learn: 1.6438318	total: 3.67s	remaining: 746ms
# 123:	learn: 1.6437215	total: 3.69s	remaining: 714ms
# 124:	learn: 1.6433469	total: 3.7s	remaining: 682ms
# 125:	learn: 1.6431353	total: 3.72s	remaining: 649ms
# 126:	learn: 1.6428634	total: 3.73s	remaining: 618ms
# 127:	learn: 1.6427177	total: 3.75s	remaining: 586ms
# 128:	learn: 1.6422797	total: 3.77s	remaining: 555ms
# 129:	learn: 1.6420317	total: 3.78s	remaining: 524ms
# 130:	learn: 1.6417032	total: 3.8s	remaining: 493ms
# 131:	learn: 1.6415094	total: 3.81s	remaining: 462ms
# 132:	learn: 1.6414454	total: 3.83s	remaining: 432ms
# 133:	learn: 1.6412757	total: 3.84s	remaining: 401ms
# 134:	learn: 1.6409533	total: 3.86s	remaining: 371ms
# 135:	learn: 1.6406179	total: 3.87s	remaining: 342ms
# 136:	learn: 1.6403864	total: 3.89s	remaining: 313ms
# 137:	learn: 1.6401423	total: 3.91s	remaining: 283ms
# 138:	learn: 1.6399113	total: 3.92s	remaining: 254ms
# 139:	learn: 1.6396981	total: 3.94s	remaining: 225ms
# 140:	learn: 1.6395067	total: 3.95s	remaining: 196ms
# 141:	learn: 1.6391071	total: 3.97s	remaining: 168ms
# 142:	learn: 1.6386244	total: 3.99s	remaining: 139ms
# 143:	learn: 1.6382646	total: 4s	remaining: 111ms
# 144:	learn: 1.6381122	total: 4.02s	remaining: 83.1ms
# 145:	learn: 1.6379870	total: 4.03s	remaining: 55.2ms
# 146:	learn: 1.6377704	total: 4.05s	remaining: 27.5ms
# 147:	learn: 1.6374981	total: 4.06s	remaining: 0us
#  30%|███       | 3/10 [00:09<00:22,  3.15s/trial, best loss: 0.24438767991354327]0:	learn: 1.7907275	total: 17.7ms	remaining: 2.03s
# 1:	learn: 1.7896112	total: 34.3ms	remaining: 1.95s
# 2:	learn: 1.7885836	total: 51.2ms	remaining: 1.93s
# 3:	learn: 1.7874813	total: 68.3ms	remaining: 1.91s
# 4:	learn: 1.7863940	total: 86.2ms	remaining: 1.91s
# 5:	learn: 1.7855279	total: 101ms	remaining: 1.84s
# 6:	learn: 1.7845305	total: 116ms	remaining: 1.81s
# 7:	learn: 1.7835395	total: 131ms	remaining: 1.77s
# 8:	learn: 1.7825663	total: 147ms	remaining: 1.75s
# 9:	learn: 1.7816990	total: 163ms	remaining: 1.73s
# 10:	learn: 1.7807722	total: 182ms	remaining: 1.74s
# 11:	learn: 1.7798029	total: 201ms	remaining: 1.75s
# 12:	learn: 1.7788588	total: 217ms	remaining: 1.72s
# 13:	learn: 1.7779806	total: 234ms	remaining: 1.71s
# 14:	learn: 1.7771060	total: 250ms	remaining: 1.69s
# 15:	learn: 1.7761838	total: 269ms	remaining: 1.68s
# 16:	learn: 1.7753381	total: 285ms	remaining: 1.66s
# 17:	learn: 1.7744119	total: 303ms	remaining: 1.65s
# 18:	learn: 1.7735804	total: 318ms	remaining: 1.63s
# 19:	learn: 1.7726791	total: 336ms	remaining: 1.61s
# 20:	learn: 1.7718278	total: 352ms	remaining: 1.59s
# 21:	learn: 1.7709431	total: 370ms	remaining: 1.58s
# 22:	learn: 1.7701112	total: 390ms	remaining: 1.58s
# 23:	learn: 1.7692923	total: 408ms	remaining: 1.56s
# 24:	learn: 1.7684278	total: 424ms	remaining: 1.54s
# 25:	learn: 1.7676150	total: 442ms	remaining: 1.53s
# 26:	learn: 1.7668952	total: 462ms	remaining: 1.52s
# 27:	learn: 1.7660836	total: 480ms	remaining: 1.51s
# 28:	learn: 1.7652421	total: 497ms	remaining: 1.49s
# 29:	learn: 1.7644511	total: 515ms	remaining: 1.48s
# 30:	learn: 1.7637550	total: 532ms	remaining: 1.46s
# 31:	learn: 1.7630663	total: 547ms	remaining: 1.44s
# 32:	learn: 1.7622930	total: 566ms	remaining: 1.42s
# 33:	learn: 1.7615687	total: 584ms	remaining: 1.41s
# 34:	learn: 1.7608513	total: 600ms	remaining: 1.39s
# 35:	learn: 1.7601111	total: 619ms	remaining: 1.38s
# 36:	learn: 1.7594656	total: 640ms	remaining: 1.37s
# 37:	learn: 1.7587392	total: 658ms	remaining: 1.35s
# 38:	learn: 1.7581007	total: 677ms	remaining: 1.34s
# 39:	learn: 1.7573900	total: 694ms	remaining: 1.32s
# 40:	learn: 1.7567282	total: 709ms	remaining: 1.3s
# 41:	learn: 1.7560325	total: 725ms	remaining: 1.28s
# 42:	learn: 1.7553608	total: 741ms	remaining: 1.26s
# 43:	learn: 1.7547342	total: 758ms	remaining: 1.24s
# 44:	learn: 1.7541330	total: 776ms	remaining: 1.22s
# 45:	learn: 1.7534766	total: 793ms	remaining: 1.21s
# 46:	learn: 1.7528335	total: 810ms	remaining: 1.19s
# 47:	learn: 1.7522590	total: 826ms	remaining: 1.17s
# 48:	learn: 1.7516383	total: 845ms	remaining: 1.16s
# 49:	learn: 1.7510096	total: 862ms	remaining: 1.14s
# 50:	learn: 1.7503753	total: 881ms	remaining: 1.12s
# 51:	learn: 1.7497462	total: 901ms	remaining: 1.11s
# 52:	learn: 1.7492043	total: 915ms	remaining: 1.09s
# 53:	learn: 1.7485942	total: 931ms	remaining: 1.07s
# 54:	learn: 1.7480297	total: 949ms	remaining: 1.05s
# 55:	learn: 1.7474381	total: 963ms	remaining: 1.03s
# 56:	learn: 1.7469090	total: 978ms	remaining: 1.01s
# 57:	learn: 1.7463555	total: 994ms	remaining: 994ms
# 58:	learn: 1.7458064	total: 1.01s	remaining: 977ms
# 59:	learn: 1.7452323	total: 1.03s	remaining: 962ms
# 60:	learn: 1.7446756	total: 1.05s	remaining: 945ms
# 61:	learn: 1.7442343	total: 1.07s	remaining: 930ms
# 62:	learn: 1.7436877	total: 1.09s	remaining: 915ms
# 63:	learn: 1.7432430	total: 1.1s	remaining: 898ms
# 64:	learn: 1.7427016	total: 1.12s	remaining: 882ms
# 65:	learn: 1.7422516	total: 1.14s	remaining: 862ms
# 66:	learn: 1.7417539	total: 1.15s	remaining: 844ms
# 67:	learn: 1.7413090	total: 1.17s	remaining: 825ms
# 68:	learn: 1.7408037	total: 1.19s	remaining: 808ms
# 69:	learn: 1.7403022	total: 1.21s	remaining: 792ms
# 70:	learn: 1.7398180	total: 1.22s	remaining: 774ms
# 71:	learn: 1.7394121	total: 1.24s	remaining: 757ms
# 72:	learn: 1.7389440	total: 1.25s	remaining: 740ms
# 73:	learn: 1.7384945	total: 1.27s	remaining: 723ms
# 74:	learn: 1.7380198	total: 1.29s	remaining: 705ms
# 75:	learn: 1.7375529	total: 1.31s	remaining: 689ms
# 76:	learn: 1.7370534	total: 1.33s	remaining: 672ms
# 77:	learn: 1.7366137	total: 1.34s	remaining: 654ms
# 78:	learn: 1.7361281	total: 1.36s	remaining: 636ms
# 79:	learn: 1.7357658	total: 1.37s	remaining: 618ms
# 80:	learn: 1.7353215	total: 1.39s	remaining: 600ms
# 81:	learn: 1.7349085	total: 1.41s	remaining: 583ms
# 82:	learn: 1.7345374	total: 1.42s	remaining: 566ms
# 83:	learn: 1.7340798	total: 1.44s	remaining: 548ms
# 84:	learn: 1.7336248	total: 1.46s	remaining: 532ms
# 85:	learn: 1.7332264	total: 1.48s	remaining: 515ms
# 86:	learn: 1.7328184	total: 1.5s	remaining: 499ms
# 87:	learn: 1.7323701	total: 1.52s	remaining: 482ms
# 88:	learn: 1.7319897	total: 1.53s	remaining: 465ms
# 89:	learn: 1.7316017	total: 1.55s	remaining: 448ms
# 90:	learn: 1.7312272	total: 1.57s	remaining: 430ms
# 91:	learn: 1.7308138	total: 1.58s	remaining: 414ms
# 92:	learn: 1.7304891	total: 1.6s	remaining: 397ms
# 93:	learn: 1.7301350	total: 1.63s	remaining: 381ms
# 94:	learn: 1.7298553	total: 1.65s	remaining: 364ms
# 95:	learn: 1.7295153	total: 1.67s	remaining: 349ms
# 96:	learn: 1.7291549	total: 1.7s	remaining: 333ms
# 97:	learn: 1.7287872	total: 1.73s	remaining: 318ms
# 98:	learn: 1.7284124	total: 1.76s	remaining: 302ms
# 99:	learn: 1.7280416	total: 1.79s	remaining: 286ms
# 100:	learn: 1.7277578	total: 1.81s	remaining: 269ms
# 101:	learn: 1.7274222	total: 1.84s	remaining: 253ms
# 102:	learn: 1.7271112	total: 1.87s	remaining: 236ms
# 103:	learn: 1.7267673	total: 1.9s	remaining: 219ms
# 104:	learn: 1.7264393	total: 1.93s	remaining: 202ms
# 105:	learn: 1.7261111	total: 1.96s	remaining: 185ms
# 106:	learn: 1.7257829	total: 1.99s	remaining: 167ms
# 107:	learn: 1.7254667	total: 2.02s	remaining: 149ms
# 108:	learn: 1.7250876	total: 2.05s	remaining: 131ms
# 109:	learn: 1.7247812	total: 2.08s	remaining: 113ms
# 110:	learn: 1.7245085	total: 2.1s	remaining: 94.6ms
# 111:	learn: 1.7242392	total: 2.13s	remaining: 76ms
# 112:	learn: 1.7239903	total: 2.16s	remaining: 57.3ms
# 113:	learn: 1.7236509	total: 2.19s	remaining: 38.4ms
# 114:	learn: 1.7233583	total: 2.22s	remaining: 19.3ms
# 115:	learn: 1.7230273	total: 2.25s	remaining: 0us
#  40%|████      | 4/10 [00:11<00:17,  2.84s/trial, best loss: 0.24438767991354327]0:	learn: 1.7811953	total: 57.6ms	remaining: 3s
# 1:	learn: 1.7722421	total: 112ms	remaining: 2.85s
# 2:	learn: 1.7639535	total: 165ms	remaining: 2.75s
# 3:	learn: 1.7564510	total: 221ms	remaining: 2.71s
# 4:	learn: 1.7499574	total: 277ms	remaining: 2.66s
# 5:	learn: 1.7439150	total: 383ms	remaining: 3s
# 6:	learn: 1.7385974	total: 438ms	remaining: 2.88s
# 7:	learn: 1.7336302	total: 489ms	remaining: 2.75s
# 8:	learn: 1.7293281	total: 542ms	remaining: 2.65s
# 9:	learn: 1.7256595	total: 595ms	remaining: 2.56s
# 10:	learn: 1.7224935	total: 649ms	remaining: 2.48s
# 11:	learn: 1.7191865	total: 701ms	remaining: 2.4s
# 12:	learn: 1.7162166	total: 758ms	remaining: 2.33s
# 13:	learn: 1.7137911	total: 814ms	remaining: 2.27s
# 14:	learn: 1.7114272	total: 867ms	remaining: 2.2s
# 15:	learn: 1.7091940	total: 918ms	remaining: 2.12s
# 16:	learn: 1.7072276	total: 969ms	remaining: 2.05s
# 17:	learn: 1.7055717	total: 1.01s	remaining: 1.96s
# 18:	learn: 1.7038821	total: 1.07s	remaining: 1.91s
# 19:	learn: 1.7029121	total: 1.09s	remaining: 1.8s
# 20:	learn: 1.7017236	total: 1.13s	remaining: 1.72s
# 21:	learn: 1.7002026	total: 1.18s	remaining: 1.67s
# 22:	learn: 1.6992373	total: 1.24s	remaining: 1.62s
# 23:	learn: 1.6984447	total: 1.28s	remaining: 1.55s
# 24:	learn: 1.6973796	total: 1.33s	remaining: 1.49s
# 25:	learn: 1.6962988	total: 1.38s	remaining: 1.44s
# 26:	learn: 1.6950264	total: 1.44s	remaining: 1.39s
# 27:	learn: 1.6939532	total: 1.5s	remaining: 1.34s
# 28:	learn: 1.6930849	total: 1.55s	remaining: 1.28s
# 29:	learn: 1.6924500	total: 1.6s	remaining: 1.23s
# 30:	learn: 1.6917041	total: 1.66s	remaining: 1.18s
# 31:	learn: 1.6905921	total: 1.72s	remaining: 1.13s
# 32:	learn: 1.6899535	total: 1.78s	remaining: 1.08s
# 33:	learn: 1.6890592	total: 1.83s	remaining: 1.02s
# 34:	learn: 1.6882568	total: 1.89s	remaining: 971ms
# 35:	learn: 1.6875374	total: 1.94s	remaining: 918ms
# 36:	learn: 1.6868413	total: 2s	remaining: 864ms
# 37:	learn: 1.6860933	total: 2.05s	remaining: 808ms
# 38:	learn: 1.6854442	total: 2.1s	remaining: 755ms
# 39:	learn: 1.6850257	total: 2.16s	remaining: 702ms
# 40:	learn: 1.6844972	total: 2.21s	remaining: 649ms
# 41:	learn: 1.6842115	total: 2.27s	remaining: 594ms
# 42:	learn: 1.6837087	total: 2.33s	remaining: 541ms
# 43:	learn: 1.6832204	total: 2.38s	remaining: 487ms
# 44:	learn: 1.6825907	total: 2.43s	remaining: 433ms
# 45:	learn: 1.6822758	total: 2.48s	remaining: 378ms
# 46:	learn: 1.6817747	total: 2.54s	remaining: 324ms
# 47:	learn: 1.6812440	total: 2.6s	remaining: 271ms
# 48:	learn: 1.6807082	total: 2.65s	remaining: 217ms
# 49:	learn: 1.6802448	total: 2.71s	remaining: 162ms
# 50:	learn: 1.6797137	total: 2.76s	remaining: 108ms
# 51:	learn: 1.6793648	total: 2.81s	remaining: 54.1ms
# 52:	learn: 1.6789655	total: 2.87s	remaining: 0us
#  50%|█████     | 5/10 [00:14<00:14,  2.90s/trial, best loss: 0.24438767991354327]0:	learn: 1.7671579	total: 62.2ms	remaining: 6.59s
# 1:	learn: 1.7489775	total: 116ms	remaining: 6.07s
# 2:	learn: 1.7350381	total: 173ms	remaining: 5.99s
# 3:	learn: 1.7239245	total: 225ms	remaining: 5.79s
# 4:	learn: 1.7157968	total: 280ms	remaining: 5.71s
# 5:	learn: 1.7088253	total: 338ms	remaining: 5.69s
# 6:	learn: 1.7033861	total: 392ms	remaining: 5.6s
# 7:	learn: 1.6988007	total: 446ms	remaining: 5.52s
# 8:	learn: 1.6947718	total: 502ms	remaining: 5.46s
# 9:	learn: 1.6915372	total: 563ms	remaining: 5.46s
# 10:	learn: 1.6888679	total: 616ms	remaining: 5.38s
# 11:	learn: 1.6864587	total: 673ms	remaining: 5.33s
# 12:	learn: 1.6846824	total: 728ms	remaining: 5.27s
# 13:	learn: 1.6831347	total: 789ms	remaining: 5.24s
# 14:	learn: 1.6813790	total: 844ms	remaining: 5.18s
# 15:	learn: 1.6801239	total: 898ms	remaining: 5.11s
# 16:	learn: 1.6787797	total: 950ms	remaining: 5.03s
# 17:	learn: 1.6777572	total: 1s	remaining: 4.97s
# 18:	learn: 1.6766549	total: 1.06s	remaining: 4.89s
# 19:	learn: 1.6756171	total: 1.11s	remaining: 4.83s
# 20:	learn: 1.6746955	total: 1.17s	remaining: 4.79s
# 21:	learn: 1.6735951	total: 1.23s	remaining: 4.74s
# 22:	learn: 1.6726437	total: 1.29s	remaining: 4.7s
# 23:	learn: 1.6715716	total: 1.34s	remaining: 4.63s
# 24:	learn: 1.6709653	total: 1.39s	remaining: 4.57s
# 25:	learn: 1.6701540	total: 1.45s	remaining: 4.52s
# 26:	learn: 1.6692012	total: 1.5s	remaining: 4.45s
# 27:	learn: 1.6683623	total: 1.55s	remaining: 4.39s
# 28:	learn: 1.6674380	total: 1.61s	remaining: 4.33s
# 29:	learn: 1.6669478	total: 1.67s	remaining: 4.29s
# 30:	learn: 1.6661068	total: 1.73s	remaining: 4.24s
# 31:	learn: 1.6656056	total: 1.79s	remaining: 4.19s
# 32:	learn: 1.6650701	total: 1.85s	remaining: 4.15s
# 33:	learn: 1.6640831	total: 1.91s	remaining: 4.1s
# 34:	learn: 1.6634133	total: 1.97s	remaining: 4.04s
# 35:	learn: 1.6626372	total: 2.02s	remaining: 3.97s
# 36:	learn: 1.6619197	total: 2.07s	remaining: 3.92s
# 37:	learn: 1.6607722	total: 2.13s	remaining: 3.87s
# 38:	learn: 1.6599648	total: 2.19s	remaining: 3.81s
# 39:	learn: 1.6594517	total: 2.24s	remaining: 3.75s
# 40:	learn: 1.6584864	total: 2.29s	remaining: 3.69s
# 41:	learn: 1.6579564	total: 2.32s	remaining: 3.6s
# 42:	learn: 1.6572161	total: 2.36s	remaining: 3.51s
# 43:	learn: 1.6565122	total: 2.39s	remaining: 3.42s
# 44:	learn: 1.6558055	total: 2.42s	remaining: 3.33s
# 45:	learn: 1.6553299	total: 2.45s	remaining: 3.24s
# 46:	learn: 1.6545641	total: 2.48s	remaining: 3.17s
# 47:	learn: 1.6537533	total: 2.51s	remaining: 3.08s
# 48:	learn: 1.6532825	total: 2.54s	remaining: 3.01s
# 49:	learn: 1.6526960	total: 2.58s	remaining: 2.94s
# 50:	learn: 1.6518581	total: 2.61s	remaining: 2.86s
# 51:	learn: 1.6513193	total: 2.64s	remaining: 2.79s
# 52:	learn: 1.6509238	total: 2.67s	remaining: 2.72s
# 53:	learn: 1.6504064	total: 2.7s	remaining: 2.65s
# 54:	learn: 1.6501014	total: 2.73s	remaining: 2.58s
# 55:	learn: 1.6496127	total: 2.79s	remaining: 2.54s
# 56:	learn: 1.6492010	total: 2.82s	remaining: 2.48s
# 57:	learn: 1.6488700	total: 2.85s	remaining: 2.41s
# 58:	learn: 1.6484294	total: 2.88s	remaining: 2.35s
# 59:	learn: 1.6479357	total: 2.91s	remaining: 2.28s
# 60:	learn: 1.6476646	total: 2.94s	remaining: 2.22s
# 61:	learn: 1.6472946	total: 2.98s	remaining: 2.16s
# 62:	learn: 1.6468617	total: 3.01s	remaining: 2.1s
# 63:	learn: 1.6464341	total: 3.04s	remaining: 2.04s
# 64:	learn: 1.6458013	total: 3.07s	remaining: 1.98s
# 65:	learn: 1.6450510	total: 3.1s	remaining: 1.93s
# 66:	learn: 1.6444057	total: 3.13s	remaining: 1.87s
# 67:	learn: 1.6441795	total: 3.16s	remaining: 1.81s
# 68:	learn: 1.6437550	total: 3.19s	remaining: 1.76s
# 69:	learn: 1.6429589	total: 3.23s	remaining: 1.71s
# 70:	learn: 1.6425218	total: 3.26s	remaining: 1.65s
# 71:	learn: 1.6419440	total: 3.29s	remaining: 1.6s
# 72:	learn: 1.6415443	total: 3.32s	remaining: 1.55s
# 73:	learn: 1.6412042	total: 3.35s	remaining: 1.5s
# 74:	learn: 1.6406205	total: 3.39s	remaining: 1.45s
# 75:	learn: 1.6398465	total: 3.42s	remaining: 1.4s
# 76:	learn: 1.6395415	total: 3.45s	remaining: 1.34s
# 77:	learn: 1.6388617	total: 3.48s	remaining: 1.29s
# 78:	learn: 1.6384981	total: 3.52s	remaining: 1.25s
# 79:	learn: 1.6380575	total: 3.54s	remaining: 1.2s
# 80:	learn: 1.6376885	total: 3.58s	remaining: 1.15s
# 81:	learn: 1.6373872	total: 3.61s	remaining: 1.1s
# 82:	learn: 1.6369336	total: 3.64s	remaining: 1.05s
# 83:	learn: 1.6364317	total: 3.67s	remaining: 1.01s
# 84:	learn: 1.6358113	total: 3.71s	remaining: 959ms
# 85:	learn: 1.6353443	total: 3.74s	remaining: 913ms
# 86:	learn: 1.6346654	total: 3.77s	remaining: 866ms
# 87:	learn: 1.6344354	total: 3.8s	remaining: 820ms
# 88:	learn: 1.6339948	total: 3.83s	remaining: 775ms
# 89:	learn: 1.6335635	total: 3.87s	remaining: 731ms
# 90:	learn: 1.6330637	total: 3.9s	remaining: 685ms
# 91:	learn: 1.6327432	total: 3.93s	remaining: 641ms
# 92:	learn: 1.6322748	total: 3.96s	remaining: 596ms
# 93:	learn: 1.6318045	total: 3.99s	remaining: 552ms
# 94:	learn: 1.6313521	total: 4.02s	remaining: 508ms
# 95:	learn: 1.6309730	total: 4.05s	remaining: 464ms
# 96:	learn: 1.6306210	total: 4.09s	remaining: 421ms
# 97:	learn: 1.6303251	total: 4.12s	remaining: 378ms
# 98:	learn: 1.6300864	total: 4.15s	remaining: 336ms
# 99:	learn: 1.6296868	total: 4.18s	remaining: 293ms
# 100:	learn: 1.6291232	total: 4.21s	remaining: 250ms
# 101:	learn: 1.6287352	total: 4.25s	remaining: 208ms
# 102:	learn: 1.6281175	total: 4.28s	remaining: 166ms
# 103:	learn: 1.6276906	total: 4.31s	remaining: 124ms
# 104:	learn: 1.6271888	total: 4.34s	remaining: 82.7ms
# 105:	learn: 1.6268856	total: 4.38s	remaining: 41.3ms
# 106:	learn: 1.6264485	total: 4.41s	remaining: 0us
#  60%|██████    | 6/10 [00:18<00:13,  3.45s/trial, best loss: 0.24438767991354327]0:	learn: 1.7875934	total: 431ms	remaining: 21.5s
# 1:	learn: 1.7838074	total: 1.78s	remaining: 43.7s
# 2:	learn: 1.7800363	total: 3.4s	remaining: 54.4s
# 3:	learn: 1.7767807	total: 3.43s	remaining: 40.3s
# 4:	learn: 1.7735325	total: 3.5s	remaining: 32.2s
# 5:	learn: 1.7701576	total: 3.6s	remaining: 27s
# 6:	learn: 1.7669948	total: 5.45s	remaining: 34.3s
# 7:	learn: 1.7638510	total: 5.62s	remaining: 30.2s
# 8:	learn: 1.7608478	total: 6.65s	remaining: 31s
# 9:	learn: 1.7579826	total: 7.57s	remaining: 31s
# 10:	learn: 1.7551895	total: 8.49s	remaining: 30.9s
# 11:	learn: 1.7526189	total: 8.52s	remaining: 27.7s
# 12:	learn: 1.7499445	total: 9.88s	remaining: 28.9s
# 13:	learn: 1.7479895	total: 9.92s	remaining: 26.2s
# 14:	learn: 1.7454842	total: 11.5s	remaining: 27.7s
# 15:	learn: 1.7432958	total: 11.6s	remaining: 25.4s
# 16:	learn: 1.7411458	total: 11.7s	remaining: 23.3s
# 17:	learn: 1.7388702	total: 13.2s	remaining: 24.1s
# 18:	learn: 1.7366812	total: 14.1s	remaining: 23.7s
# 19:	learn: 1.7345563	total: 15s	remaining: 23.3s
# 20:	learn: 1.7325397	total: 15.9s	remaining: 22.8s
# 21:	learn: 1.7305986	total: 16.9s	remaining: 22.2s
# 22:	learn: 1.7286606	total: 18.4s	remaining: 22.4s
# 23:	learn: 1.7267568	total: 20s	remaining: 22.5s
# 24:	learn: 1.7247460	total: 21.9s	remaining: 22.7s
# 25:	learn: 1.7229099	total: 23.5s	remaining: 22.6s
# 26:	learn: 1.7211708	total: 24.6s	remaining: 21.9s
# 27:	learn: 1.7194053	total: 25.5s	remaining: 20.9s
# 28:	learn: 1.7176431	total: 26.4s	remaining: 20s
# 29:	learn: 1.7163032	total: 26.4s	remaining: 18.5s
# 30:	learn: 1.7148292	total: 26.5s	remaining: 17.1s
# 31:	learn: 1.7134302	total: 27.6s	remaining: 16.4s
# 32:	learn: 1.7118534	total: 29.2s	remaining: 15.9s
# 33:	learn: 1.7103309	total: 30.7s	remaining: 15.4s
# 34:	learn: 1.7089532	total: 32.2s	remaining: 14.7s
# 35:	learn: 1.7075551	total: 33.1s	remaining: 13.8s
# 36:	learn: 1.7061774	total: 34s	remaining: 12.9s
# 37:	learn: 1.7047444	total: 34.9s	remaining: 12s
# 38:	learn: 1.7037724	total: 35s	remaining: 10.8s
# 39:	learn: 1.7029512	total: 35s	remaining: 9.62s
# 40:	learn: 1.7015726	total: 36.5s	remaining: 8.89s
# 41:	learn: 1.7002813	total: 38s	remaining: 8.15s
# 42:	learn: 1.6989955	total: 39.8s	remaining: 7.4s
# 43:	learn: 1.6977223	total: 41.4s	remaining: 6.58s
# 44:	learn: 1.6966286	total: 42.6s	remaining: 5.68s
# 45:	learn: 1.6955820	total: 43.5s	remaining: 4.73s
# 46:	learn: 1.6945774	total: 44.4s	remaining: 3.78s
# 47:	learn: 1.6936608	total: 45.5s	remaining: 2.84s
# 48:	learn: 1.6926799	total: 47s	remaining: 1.92s
# 49:	learn: 1.6916227	total: 48.6s	remaining: 972ms
# 50:	learn: 1.6906883	total: 50.1s	remaining: 0us
#  70%|███████   | 7/10 [01:09<00:56, 18.80s/trial, best loss: 0.24438767991354327]0:	learn: 1.7906941	total: 16.4ms	remaining: 1.63s
# 1:	learn: 1.7896430	total: 30.9ms	remaining: 1.51s
# 2:	learn: 1.7886216	total: 44.9ms	remaining: 1.45s
# 3:	learn: 1.7875975	total: 58.5ms	remaining: 1.4s
# 4:	learn: 1.7865870	total: 72.5ms	remaining: 1.38s
# 5:	learn: 1.7856045	total: 84ms	remaining: 1.32s
# 6:	learn: 1.7846350	total: 96.4ms	remaining: 1.28s
# 7:	learn: 1.7836785	total: 108ms	remaining: 1.24s
# 8:	learn: 1.7827179	total: 121ms	remaining: 1.22s
# 9:	learn: 1.7818358	total: 134ms	remaining: 1.2s
# 10:	learn: 1.7808986	total: 147ms	remaining: 1.19s
# 11:	learn: 1.7800290	total: 159ms	remaining: 1.17s
# 12:	learn: 1.7791312	total: 170ms	remaining: 1.14s
# 13:	learn: 1.7782288	total: 184ms	remaining: 1.13s
# 14:	learn: 1.7773382	total: 197ms	remaining: 1.11s
# 15:	learn: 1.7764748	total: 210ms	remaining: 1.1s
# 16:	learn: 1.7756213	total: 224ms	remaining: 1.09s
# 17:	learn: 1.7747635	total: 239ms	remaining: 1.09s
# 18:	learn: 1.7739621	total: 252ms	remaining: 1.07s
# 19:	learn: 1.7731257	total: 266ms	remaining: 1.06s
# 20:	learn: 1.7723519	total: 281ms	remaining: 1.06s
# 21:	learn: 1.7715504	total: 294ms	remaining: 1.04s
# 22:	learn: 1.7707898	total: 307ms	remaining: 1.03s
# 23:	learn: 1.7699936	total: 319ms	remaining: 1.01s
# 24:	learn: 1.7692076	total: 331ms	remaining: 993ms
# 25:	learn: 1.7684784	total: 343ms	remaining: 976ms
# 26:	learn: 1.7677111	total: 356ms	remaining: 963ms
# 27:	learn: 1.7669985	total: 368ms	remaining: 947ms
# 28:	learn: 1.7663220	total: 380ms	remaining: 930ms
# 29:	learn: 1.7655931	total: 393ms	remaining: 917ms
# 30:	learn: 1.7649107	total: 405ms	remaining: 902ms
# 31:	learn: 1.7641863	total: 420ms	remaining: 892ms
# 32:	learn: 1.7634857	total: 434ms	remaining: 881ms
# 33:	learn: 1.7628031	total: 448ms	remaining: 869ms
# 34:	learn: 1.7621047	total: 462ms	remaining: 858ms
# 35:	learn: 1.7614152	total: 476ms	remaining: 845ms
# 36:	learn: 1.7607344	total: 488ms	remaining: 832ms
# 37:	learn: 1.7600731	total: 501ms	remaining: 818ms
# 38:	learn: 1.7594324	total: 513ms	remaining: 803ms
# 39:	learn: 1.7588408	total: 525ms	remaining: 787ms
# 40:	learn: 1.7581912	total: 538ms	remaining: 774ms
# 41:	learn: 1.7575615	total: 553ms	remaining: 763ms
# 42:	learn: 1.7569275	total: 565ms	remaining: 748ms
# 43:	learn: 1.7563647	total: 575ms	remaining: 732ms
# 44:	learn: 1.7557820	total: 587ms	remaining: 718ms
# 45:	learn: 1.7551831	total: 599ms	remaining: 703ms
# 46:	learn: 1.7546370	total: 611ms	remaining: 690ms
# 47:	learn: 1.7540823	total: 625ms	remaining: 677ms
# 48:	learn: 1.7534898	total: 638ms	remaining: 664ms
# 49:	learn: 1.7529170	total: 651ms	remaining: 651ms
# 50:	learn: 1.7523767	total: 664ms	remaining: 638ms
# 51:	learn: 1.7518422	total: 676ms	remaining: 624ms
# 52:	learn: 1.7512764	total: 690ms	remaining: 612ms
# 53:	learn: 1.7507176	total: 704ms	remaining: 600ms
# 54:	learn: 1.7501773	total: 715ms	remaining: 585ms
# 55:	learn: 1.7496318	total: 727ms	remaining: 571ms
# 56:	learn: 1.7491002	total: 739ms	remaining: 557ms
# 57:	learn: 1.7486067	total: 753ms	remaining: 545ms
# 58:	learn: 1.7480797	total: 767ms	remaining: 533ms
# 59:	learn: 1.7475594	total: 781ms	remaining: 520ms
# 60:	learn: 1.7470562	total: 793ms	remaining: 507ms
# 61:	learn: 1.7465571	total: 808ms	remaining: 495ms
# 62:	learn: 1.7460917	total: 822ms	remaining: 483ms
# 63:	learn: 1.7455947	total: 837ms	remaining: 471ms
# 64:	learn: 1.7451369	total: 851ms	remaining: 458ms
# 65:	learn: 1.7446876	total: 863ms	remaining: 445ms
# 66:	learn: 1.7442609	total: 874ms	remaining: 430ms
# 67:	learn: 1.7438251	total: 895ms	remaining: 421ms
# 68:	learn: 1.7434115	total: 918ms	remaining: 413ms
# 69:	learn: 1.7429580	total: 938ms	remaining: 402ms
# 70:	learn: 1.7425342	total: 957ms	remaining: 391ms
# 71:	learn: 1.7421152	total: 973ms	remaining: 378ms
# 72:	learn: 1.7417087	total: 984ms	remaining: 364ms
# 73:	learn: 1.7412795	total: 996ms	remaining: 350ms
# 74:	learn: 1.7409076	total: 1.01s	remaining: 336ms
# 75:	learn: 1.7404767	total: 1.02s	remaining: 323ms
# 76:	learn: 1.7400452	total: 1.04s	remaining: 310ms
# 77:	learn: 1.7396533	total: 1.08s	remaining: 304ms
# 78:	learn: 1.7392435	total: 1.09s	remaining: 291ms
# 79:	learn: 1.7388786	total: 1.11s	remaining: 277ms
# 80:	learn: 1.7384656	total: 1.12s	remaining: 263ms
# 81:	learn: 1.7380876	total: 1.14s	remaining: 249ms
# 82:	learn: 1.7376837	total: 1.15s	remaining: 235ms
# 83:	learn: 1.7373188	total: 1.16s	remaining: 221ms
# 84:	learn: 1.7369479	total: 1.17s	remaining: 207ms
# 85:	learn: 1.7366081	total: 1.18s	remaining: 193ms
# 86:	learn: 1.7362295	total: 1.2s	remaining: 179ms
# 87:	learn: 1.7358595	total: 1.21s	remaining: 165ms
# 88:	learn: 1.7355174	total: 1.22s	remaining: 151ms
# 89:	learn: 1.7351561	total: 1.23s	remaining: 137ms
# 90:	learn: 1.7348379	total: 1.24s	remaining: 123ms
# 91:	learn: 1.7345198	total: 1.26s	remaining: 109ms
# 92:	learn: 1.7342198	total: 1.27s	remaining: 95.6ms
# 93:	learn: 1.7338952	total: 1.28s	remaining: 82ms
# 94:	learn: 1.7335850	total: 1.3s	remaining: 68.3ms
# 95:	learn: 1.7332640	total: 1.31s	remaining: 54.6ms
# 96:	learn: 1.7329465	total: 1.32s	remaining: 40.9ms
# 97:	learn: 1.7326672	total: 1.33s	remaining: 27.3ms
# 98:	learn: 1.7323252	total: 1.35s	remaining: 13.6ms
# 99:	learn: 1.7320364	total: 1.36s	remaining: 0us
#  80%|████████  | 8/10 [01:10<00:26, 13.27s/trial, best loss: 0.24438767991354327]0:	learn: 1.7894631	total: 15.3ms	remaining: 3.02s
# 1:	learn: 1.7872330	total: 29.5ms	remaining: 2.89s
# 2:	learn: 1.7850668	total: 43.7ms	remaining: 2.84s
# 3:	learn: 1.7829626	total: 57.2ms	remaining: 2.77s
# 4:	learn: 1.7809182	total: 71.9ms	remaining: 2.78s
# 5:	learn: 1.7789317	total: 86.9ms	remaining: 2.78s
# 6:	learn: 1.7770012	total: 104ms	remaining: 2.85s
# 7:	learn: 1.7751249	total: 122ms	remaining: 2.9s
# 8:	learn: 1.7733012	total: 136ms	remaining: 2.87s
# 9:	learn: 1.7715283	total: 149ms	remaining: 2.8s
# 10:	learn: 1.7698071	total: 161ms	remaining: 2.74s
# 11:	learn: 1.7681283	total: 174ms	remaining: 2.69s
# 12:	learn: 1.7664989	total: 186ms	remaining: 2.65s
# 13:	learn: 1.7649086	total: 198ms	remaining: 2.61s
# 14:	learn: 1.7633621	total: 211ms	remaining: 2.58s
# 15:	learn: 1.7618609	total: 224ms	remaining: 2.55s
# 16:	learn: 1.7603963	total: 237ms	remaining: 2.53s
# 17:	learn: 1.7589680	total: 251ms	remaining: 2.51s
# 18:	learn: 1.7575786	total: 265ms	remaining: 2.5s
# 19:	learn: 1.7562261	total: 278ms	remaining: 2.48s
# 20:	learn: 1.7549082	total: 292ms	remaining: 2.46s
# 21:	learn: 1.7536261	total: 305ms	remaining: 2.44s
# 22:	learn: 1.7523790	total: 317ms	remaining: 2.42s
# 23:	learn: 1.7511581	total: 332ms	remaining: 2.4s
# 24:	learn: 1.7499699	total: 345ms	remaining: 2.39s
# 25:	learn: 1.7488169	total: 358ms	remaining: 2.37s
# 26:	learn: 1.7476893	total: 371ms	remaining: 2.35s
# 27:	learn: 1.7465955	total: 383ms	remaining: 2.33s
# 28:	learn: 1.7455312	total: 394ms	remaining: 2.29s
# 29:	learn: 1.7444956	total: 405ms	remaining: 2.27s
# 30:	learn: 1.7434771	total: 417ms	remaining: 2.25s
# 31:	learn: 1.7424943	total: 428ms	remaining: 2.22s
# 32:	learn: 1.7415270	total: 441ms	remaining: 2.21s
# 33:	learn: 1.7405763	total: 455ms	remaining: 2.19s
# 34:	learn: 1.7396664	total: 470ms	remaining: 2.19s
# 35:	learn: 1.7387698	total: 485ms	remaining: 2.18s
# 36:	learn: 1.7379059	total: 497ms	remaining: 2.16s
# 37:	learn: 1.7370823	total: 510ms	remaining: 2.15s
# 38:	learn: 1.7362622	total: 522ms	remaining: 2.13s
# 39:	learn: 1.7354744	total: 537ms	remaining: 2.12s
# 40:	learn: 1.7347263	total: 550ms	remaining: 2.11s
# 41:	learn: 1.7339380	total: 562ms	remaining: 2.09s
# 42:	learn: 1.7331787	total: 574ms	remaining: 2.07s
# 43:	learn: 1.7324550	total: 586ms	remaining: 2.05s
# 44:	learn: 1.7317505	total: 598ms	remaining: 2.03s
# 45:	learn: 1.7310455	total: 609ms	remaining: 2.01s
# 46:	learn: 1.7303762	total: 621ms	remaining: 1.99s
# 47:	learn: 1.7297367	total: 632ms	remaining: 1.97s
# 48:	learn: 1.7290688	total: 643ms	remaining: 1.96s
# 49:	learn: 1.7284487	total: 656ms	remaining: 1.94s
# 50:	learn: 1.7278431	total: 669ms	remaining: 1.93s
# 51:	learn: 1.7272538	total: 681ms	remaining: 1.91s
# 52:	learn: 1.7266533	total: 694ms	remaining: 1.9s
# 53:	learn: 1.7260964	total: 706ms	remaining: 1.88s
# 54:	learn: 1.7255131	total: 720ms	remaining: 1.87s
# 55:	learn: 1.7249451	total: 734ms	remaining: 1.86s
# 56:	learn: 1.7243978	total: 749ms	remaining: 1.85s
# 57:	learn: 1.7238890	total: 761ms	remaining: 1.83s
# 58:	learn: 1.7233668	total: 774ms	remaining: 1.82s
# 59:	learn: 1.7228832	total: 786ms	remaining: 1.81s
# 60:	learn: 1.7224092	total: 798ms	remaining: 1.79s
# 61:	learn: 1.7219507	total: 809ms	remaining: 1.77s
# 62:	learn: 1.7215016	total: 820ms	remaining: 1.76s
# 63:	learn: 1.7210576	total: 832ms	remaining: 1.74s
# 64:	learn: 1.7206185	total: 843ms	remaining: 1.73s
# 65:	learn: 1.7201908	total: 856ms	remaining: 1.71s
# 66:	learn: 1.7197801	total: 869ms	remaining: 1.7s
# 67:	learn: 1.7193802	total: 881ms	remaining: 1.68s
# 68:	learn: 1.7189897	total: 893ms	remaining: 1.67s
# 69:	learn: 1.7186120	total: 904ms	remaining: 1.65s
# 70:	learn: 1.7182398	total: 916ms	remaining: 1.64s
# 71:	learn: 1.7178392	total: 930ms	remaining: 1.63s
# 72:	learn: 1.7174786	total: 944ms	remaining: 1.62s
# 73:	learn: 1.7171034	total: 958ms	remaining: 1.61s
# 74:	learn: 1.7167391	total: 973ms	remaining: 1.59s
# 75:	learn: 1.7164052	total: 986ms	remaining: 1.58s
# 76:	learn: 1.7160436	total: 998ms	remaining: 1.57s
# 77:	learn: 1.7157146	total: 1.01s	remaining: 1.55s
# 78:	learn: 1.7153688	total: 1.02s	remaining: 1.54s
# 79:	learn: 1.7150616	total: 1.03s	remaining: 1.52s
# 80:	learn: 1.7147308	total: 1.04s	remaining: 1.51s
# 81:	learn: 1.7144395	total: 1.06s	remaining: 1.49s
# 82:	learn: 1.7141528	total: 1.07s	remaining: 1.48s
# 83:	learn: 1.7138690	total: 1.08s	remaining: 1.47s
# 84:	learn: 1.7135947	total: 1.09s	remaining: 1.46s
# 85:	learn: 1.7133308	total: 1.11s	remaining: 1.44s
# 86:	learn: 1.7130299	total: 1.12s	remaining: 1.43s
# 87:	learn: 1.7127736	total: 1.13s	remaining: 1.41s
# 88:	learn: 1.7124932	total: 1.14s	remaining: 1.4s
# 89:	learn: 1.7122171	total: 1.15s	remaining: 1.38s
# 90:	learn: 1.7119760	total: 1.17s	remaining: 1.37s
# 91:	learn: 1.7117042	total: 1.18s	remaining: 1.36s
# 92:	learn: 1.7114419	total: 1.2s	remaining: 1.35s
# 93:	learn: 1.7111877	total: 1.21s	remaining: 1.33s
# 94:	learn: 1.7109642	total: 1.22s	remaining: 1.32s
# 95:	learn: 1.7107453	total: 1.23s	remaining: 1.31s
# 96:	learn: 1.7105086	total: 1.24s	remaining: 1.29s
# 97:	learn: 1.7102731	total: 1.25s	remaining: 1.28s
# 98:	learn: 1.7100688	total: 1.27s	remaining: 1.27s
# 99:	learn: 1.7098652	total: 1.28s	remaining: 1.25s
# 100:	learn: 1.7096587	total: 1.29s	remaining: 1.24s
# 101:	learn: 1.7094444	total: 1.3s	remaining: 1.23s
# 102:	learn: 1.7092536	total: 1.31s	remaining: 1.21s
# 103:	learn: 1.7090623	total: 1.33s	remaining: 1.2s
# 104:	learn: 1.7088714	total: 1.34s	remaining: 1.18s
# 105:	learn: 1.7086925	total: 1.35s	remaining: 1.17s
# 106:	learn: 1.7084835	total: 1.36s	remaining: 1.16s
# 107:	learn: 1.7082878	total: 1.38s	remaining: 1.15s
# 108:	learn: 1.7080873	total: 1.41s	remaining: 1.15s
# 109:	learn: 1.7079035	total: 1.43s	remaining: 1.14s
# 110:	learn: 1.7077340	total: 1.45s	remaining: 1.14s
# 111:	learn: 1.7075397	total: 1.47s	remaining: 1.13s
# 112:	learn: 1.7073532	total: 1.49s	remaining: 1.12s
# 113:	learn: 1.7072001	total: 1.52s	remaining: 1.12s
# 114:	learn: 1.7070481	total: 1.54s	remaining: 1.11s
# 115:	learn: 1.7068731	total: 1.55s	remaining: 1.1s
# 116:	learn: 1.7067222	total: 1.57s	remaining: 1.09s
# 117:	learn: 1.7065746	total: 1.59s	remaining: 1.08s
# 118:	learn: 1.7064120	total: 1.62s	remaining: 1.07s
# 119:	learn: 1.7062729	total: 1.64s	remaining: 1.06s
# 120:	learn: 1.7061343	total: 1.66s	remaining: 1.05s
# 121:	learn: 1.7059716	total: 1.68s	remaining: 1.05s
# 122:	learn: 1.7058132	total: 1.7s	remaining: 1.04s
# 123:	learn: 1.7056812	total: 1.73s	remaining: 1.03s
# 124:	learn: 1.7055299	total: 1.75s	remaining: 1.02s
# 125:	learn: 1.7053987	total: 1.76s	remaining: 1.01s
# 126:	learn: 1.7052572	total: 1.78s	remaining: 998ms
# 127:	learn: 1.7051369	total: 1.8s	remaining: 988ms
# 128:	learn: 1.7050013	total: 1.83s	remaining: 979ms
# 129:	learn: 1.7048659	total: 1.9s	remaining: 994ms
# 130:	learn: 1.7047466	total: 1.92s	remaining: 983ms
# 131:	learn: 1.7046117	total: 1.95s	remaining: 975ms
# 132:	learn: 1.7044749	total: 1.97s	remaining: 964ms
# 133:	learn: 1.7043672	total: 1.99s	remaining: 951ms
# 134:	learn: 1.7042444	total: 2.01s	remaining: 939ms
# ...
# 157:	learn: 1.7019581	total: 2.51s	remaining: 636ms
# 158:	learn: 1.7018834	total: 2.54s	remaining: 622ms
# 159:	learn: 1.7018020	total: 2.56s	remaining: 607ms
# 160:	learn: 1.7017228	total: 2.58s	remaining: 592ms
# 161:	learn: 1.7016534	total: 2.6s	remaining: 577ms
# 162:	learn: 1.7015769	total: 2.62s	remaining: 562ms
# 163:	learn: 1.7014887	total: 2.63s	remaining: 546ms
# 164:	learn: 1.7014232	total: 2.65s	remaining: 531ms
# 165:	learn: 1.7013587	total: 2.67s	remaining: 515ms
# 166:	learn: 1.7012730	total: 2.69s	remaining: 499ms
# 167:	learn: 1.7012092	total: 2.71s	remaining: 484ms
# 168:	learn: 1.7011358	total: 2.73s	remaining: 469ms
# 169:	learn: 1.7010665	total: 2.75s	remaining: 453ms
# 170:	learn: 1.7009757	total: 2.78s	remaining: 438ms
# 171:	learn: 1.7008952	total: 2.8s	remaining: 423ms
# 172:	learn: 1.7008089	total: 2.82s	remaining: 408ms
# 173:	learn: 1.7007298	total: 2.84s	remaining: 392ms
# 174:	learn: 1.7006466	total: 2.86s	remaining: 376ms
# 175:	learn: 1.7005615	total: 2.88s	remaining: 360ms
# 176:	learn: 1.7004977	total: 2.9s	remaining: 344ms
# 177:	learn: 1.7004233	total: 2.92s	remaining: 328ms
# 178:	learn: 1.7003441	total: 2.94s	remaining: 312ms
# 179:	learn: 1.7002866	total: 2.96s	remaining: 296ms
# 180:	learn: 1.7002196	total: 2.99s	remaining: 281ms
# 181:	learn: 1.7001434	total: 3.01s	remaining: 265ms
# 182:	learn: 1.7000647	total: 3.03s	remaining: 248ms
# 183:	learn: 1.7000023	total: 3.05s	remaining: 232ms
# 184:	learn: 1.6999287	total: 3.07s	remaining: 216ms
# 185:	learn: 1.6998692	total: 3.09s	remaining: 199ms
# 186:	learn: 1.6998115	total: 3.11s	remaining: 183ms
# 187:	learn: 1.6997496	total: 3.13s	remaining: 166ms
# 188:	learn: 1.6996762	total: 3.15s	remaining: 150ms
# 189:	learn: 1.6996175	total: 3.17s	remaining: 133ms
# 190:	learn: 1.6995609	total: 3.19s	remaining: 117ms
# 191:	learn: 1.6995082	total: 3.21s	remaining: 100ms
# 192:	learn: 1.6994590	total: 3.23s	remaining: 83.8ms
# 193:	learn: 1.6993825	total: 3.26s	remaining: 67.2ms
# 194:	learn: 1.6993189	total: 3.28s	remaining: 50.4ms
# 195:	learn: 1.6992646	total: 3.29s	remaining: 33.6ms
# 196:	learn: 1.6992015	total: 3.31s	remaining: 16.8ms
# 197:	learn: 1.6991470	total: 3.33s	remaining: 0us
#  90%|█████████ | 9/10 [01:14<00:10, 10.21s/trial, best loss: 0.24438767991354327]0:	learn: 1.7685151	total: 200ms	remaining: 23s
# 1:	learn: 1.7488421	total: 718ms	remaining: 40.9s
# 2:	learn: 1.7324207	total: 927ms	remaining: 34.9s
# 3:	learn: 1.7187180	total: 1.15s	remaining: 32.2s
# 4:	learn: 1.7084282	total: 1.34s	remaining: 29.8s
# 5:	learn: 1.6986639	total: 1.53s	remaining: 28.1s
# 6:	learn: 1.6910248	total: 1.71s	remaining: 26.6s
# 7:	learn: 1.6843750	total: 1.9s	remaining: 25.7s
# 8:	learn: 1.6780465	total: 2.13s	remaining: 25.3s
# 9:	learn: 1.6719586	total: 2.31s	remaining: 24.5s
# 10:	learn: 1.6672520	total: 2.5s	remaining: 23.9s
# 11:	learn: 1.6637111	total: 2.68s	remaining: 23.2s
# 12:	learn: 1.6595262	total: 2.86s	remaining: 22.7s
# 13:	learn: 1.6550527	total: 3.04s	remaining: 22.2s
# 14:	learn: 1.6523564	total: 3.23s	remaining: 21.7s
# 15:	learn: 1.6493139	total: 3.4s	remaining: 21.3s
# 16:	learn: 1.6468440	total: 3.59s	remaining: 20.9s
# 17:	learn: 1.6443545	total: 3.77s	remaining: 20.5s
# 18:	learn: 1.6409363	total: 3.96s	remaining: 20.2s
# 19:	learn: 1.6382850	total: 4.14s	remaining: 19.9s
# 20:	learn: 1.6355450	total: 4.38s	remaining: 19.8s
# 21:	learn: 1.6335053	total: 4.56s	remaining: 19.5s
# 22:	learn: 1.6312967	total: 4.75s	remaining: 19.2s
# 23:	learn: 1.6293757	total: 4.93s	remaining: 18.9s
# 24:	learn: 1.6269758	total: 5.11s	remaining: 18.6s
# 25:	learn: 1.6248127	total: 5.29s	remaining: 18.3s
# 26:	learn: 1.6230293	total: 5.48s	remaining: 18.1s
# 27:	learn: 1.6209471	total: 5.66s	remaining: 17.8s
# 28:	learn: 1.6183612	total: 5.85s	remaining: 17.6s
# 29:	learn: 1.6154989	total: 6.03s	remaining: 17.3s
# 30:	learn: 1.6130813	total: 6.22s	remaining: 17.1s
# 31:	learn: 1.6115074	total: 6.4s	remaining: 16.8s
# 32:	learn: 1.6094870	total: 6.58s	remaining: 16.6s
# 33:	learn: 1.6075168	total: 6.76s	remaining: 16.3s
# 34:	learn: 1.6054730	total: 6.96s	remaining: 16.1s
# 35:	learn: 1.6039274	total: 7.13s	remaining: 15.9s
# 36:	learn: 1.6030534	total: 7.32s	remaining: 15.6s
# 37:	learn: 1.6014836	total: 7.5s	remaining: 15.4s
# 38:	learn: 1.5998244	total: 7.69s	remaining: 15.2s
# 39:	learn: 1.5982702	total: 7.87s	remaining: 15s
# 40:	learn: 1.5966191	total: 8.06s	remaining: 14.7s
# 41:	learn: 1.5950027	total: 8.24s	remaining: 14.5s
# 42:	learn: 1.5930356	total: 8.43s	remaining: 14.3s
# 43:	learn: 1.5914252	total: 8.61s	remaining: 14.1s
# 44:	learn: 1.5897797	total: 8.8s	remaining: 13.9s
# 45:	learn: 1.5880673	total: 8.98s	remaining: 13.7s
# 46:	learn: 1.5863231	total: 9.08s	remaining: 13.3s
# 47:	learn: 1.5853552	total: 9.19s	remaining: 13s
# 48:	learn: 1.5830989	total: 9.29s	remaining: 12.7s
# 49:	learn: 1.5820014	total: 9.4s	remaining: 12.4s
# 50:	learn: 1.5808450	total: 9.51s	remaining: 12.1s
# 51:	learn: 1.5799064	total: 9.62s	remaining: 11.8s
# 52:	learn: 1.5786593	total: 9.72s	remaining: 11.6s
# 53:	learn: 1.5771869	total: 9.83s	remaining: 11.3s
# 54:	learn: 1.5753223	total: 9.94s	remaining: 11s
# 55:	learn: 1.5739583	total: 10s	remaining: 10.8s
# 56:	learn: 1.5725800	total: 10.2s	remaining: 10.5s
# 57:	learn: 1.5711035	total: 10.3s	remaining: 10.3s
# 58:	learn: 1.5698685	total: 10.4s	remaining: 10s
# 59:	learn: 1.5684850	total: 10.5s	remaining: 9.78s
# 60:	learn: 1.5672588	total: 10.6s	remaining: 9.54s
# 61:	learn: 1.5657616	total: 10.7s	remaining: 9.31s
# 62:	learn: 1.5643544	total: 10.8s	remaining: 9.08s
# 63:	learn: 1.5628127	total: 10.9s	remaining: 8.87s
# 64:	learn: 1.5610206	total: 11s	remaining: 8.64s
# 65:	learn: 1.5599010	total: 11.1s	remaining: 8.43s
# 66:	learn: 1.5577065	total: 11.2s	remaining: 8.22s
# 67:	learn: 1.5563986	total: 11.3s	remaining: 8.01s
# 68:	learn: 1.5555769	total: 11.5s	remaining: 7.8s
# 69:	learn: 1.5535425	total: 11.6s	remaining: 7.6s
# 70:	learn: 1.5513755	total: 11.7s	remaining: 7.4s
# 71:	learn: 1.5497695	total: 11.8s	remaining: 7.2s
# 72:	learn: 1.5478752	total: 11.9s	remaining: 7s
# 73:	learn: 1.5462678	total: 12s	remaining: 6.82s
# 74:	learn: 1.5445855	total: 12.2s	remaining: 6.67s
# 75:	learn: 1.5434869	total: 12.4s	remaining: 6.52s
# 76:	learn: 1.5423978	total: 12.6s	remaining: 6.37s
# 77:	learn: 1.5407227	total: 12.8s	remaining: 6.22s
# 78:	learn: 1.5388660	total: 13s	remaining: 6.07s
# 79:	learn: 1.5369149	total: 13.1s	remaining: 5.91s
# 80:	learn: 1.5351413	total: 13.3s	remaining: 5.76s
# 81:	learn: 1.5336105	total: 13.5s	remaining: 5.6s
# 82:	learn: 1.5316771	total: 13.7s	remaining: 5.44s
# 83:	learn: 1.5305432	total: 13.9s	remaining: 5.28s
# 84:	learn: 1.5293420	total: 14.1s	remaining: 5.12s
# 85:	learn: 1.5277166	total: 14.2s	remaining: 4.96s
# 86:	learn: 1.5264005	total: 14.4s	remaining: 4.8s
# 87:	learn: 1.5246482	total: 14.6s	remaining: 4.64s
# 88:	learn: 1.5234267	total: 14.8s	remaining: 4.49s
# 89:	learn: 1.5214120	total: 15s	remaining: 4.32s
# 90:	learn: 1.5199387	total: 15.2s	remaining: 4.16s
# 91:	learn: 1.5183350	total: 15.3s	remaining: 4s
# 92:	learn: 1.5172967	total: 15.6s	remaining: 3.85s
# 93:	learn: 1.5152628	total: 15.8s	remaining: 3.69s
# 94:	learn: 1.5131697	total: 15.9s	remaining: 3.52s
# 95:	learn: 1.5115031	total: 16.1s	remaining: 3.36s
# 96:	learn: 1.5100201	total: 16.5s	remaining: 3.23s
# 97:	learn: 1.5082553	total: 16.8s	remaining: 3.09s
# 98:	learn: 1.5068341	total: 17s	remaining: 2.92s
# 99:	learn: 1.5054109	total: 17.2s	remaining: 2.75s
# 100:	learn: 1.5043099	total: 17.4s	remaining: 2.58s
# 101:	learn: 1.5028273	total: 17.6s	remaining: 2.41s
# 102:	learn: 1.5012580	total: 17.8s	remaining: 2.24s
# 103:	learn: 1.4993177	total: 17.9s	remaining: 2.07s
# 104:	learn: 1.4975410	total: 18.1s	remaining: 1.9s
# 105:	learn: 1.4960770	total: 18.3s	remaining: 1.73s
# 106:	learn: 1.4941550	total: 18.5s	remaining: 1.56s
# 107:	learn: 1.4922390	total: 18.7s	remaining: 1.38s
# 108:	learn: 1.4906650	total: 18.9s	remaining: 1.21s
# 109:	learn: 1.4891405	total: 19.1s	remaining: 1.04s
# 110:	learn: 1.4878770	total: 19.2s	remaining: 867ms
# 111:	learn: 1.4856045	total: 19.4s	remaining: 694ms
# 112:	learn: 1.4834516	total: 19.6s	remaining: 521ms
# 113:	learn: 1.4822199	total: 19.8s	remaining: 347ms
# 114:	learn: 1.4808776	total: 20s	remaining: 174ms
# 115:	learn: 1.4790717	total: 20.2s	remaining: 0us
# 100%|██████████| 10/10 [01:34<00:00,  9.48s/trial, best loss: 0.24438767991354327]
# 0:	learn: 1.7150960	total: 29.7ms	remaining: 4.49s
# 1:	learn: 1.7114811	total: 46.6ms	remaining: 3.5s
# 2:	learn: 1.7105781	total: 71.1ms	remaining: 3.53s
# 3:	learn: 1.7078367	total: 99.9ms	remaining: 3.7s
# 4:	learn: 1.7070093	total: 128ms	remaining: 3.77s
# 5:	learn: 1.7065513	total: 158ms	remaining: 3.85s
# 6:	learn: 1.7065508	total: 178ms	remaining: 3.68s
# 7:	learn: 1.7065498	total: 199ms	remaining: 3.59s
# 8:	learn: 1.7065498	total: 218ms	remaining: 3.46s
# 9:	learn: 1.7065495	total: 238ms	remaining: 3.38s
# 10:	learn: 1.7065495	total: 255ms	remaining: 3.27s
# 11:	learn: 1.7065477	total: 274ms	remaining: 3.2s
# 12:	learn: 1.7059714	total: 303ms	remaining: 3.24s
# 13:	learn: 1.7054075	total: 336ms	remaining: 3.31s
# 14:	learn: 1.7052434	total: 365ms	remaining: 3.34s
# 15:	learn: 1.7050441	total: 396ms	remaining: 3.37s
# 16:	learn: 1.7046462	total: 430ms	remaining: 3.42s
# 17:	learn: 1.7045834	total: 457ms	remaining: 3.4s
# 18:	learn: 1.7044900	total: 482ms	remaining: 3.37s
# 19:	learn: 1.7044586	total: 508ms	remaining: 3.35s
# 20:	learn: 1.7042897	total: 533ms	remaining: 3.33s
# 21:	learn: 1.7042354	total: 558ms	remaining: 3.3s
# 22:	learn: 1.7042262	total: 583ms	remaining: 3.27s
# 23:	learn: 1.7041389	total: 609ms	remaining: 3.25s
# 24:	learn: 1.7041176	total: 628ms	remaining: 3.19s
# 25:	learn: 1.7040730	total: 647ms	remaining: 3.13s
# 26:	learn: 1.7040507	total: 664ms	remaining: 3.07s
# 27:	learn: 1.7040074	total: 679ms	remaining: 3s
# 28:	learn: 1.7039861	total: 693ms	remaining: 2.94s
# 29:	learn: 1.7039695	total: 708ms	remaining: 2.88s
# 30:	learn: 1.7039444	total: 722ms	remaining: 2.82s
# 31:	learn: 1.7039398	total: 738ms	remaining: 2.77s
# 32:	learn: 1.7039315	total: 755ms	remaining: 2.72s
# 33:	learn: 1.7039268	total: 772ms	remaining: 2.68s
# 34:	learn: 1.7039095	total: 789ms	remaining: 2.64s
# 35:	learn: 1.7038852	total: 806ms	remaining: 2.6s
# 36:	learn: 1.7038694	total: 822ms	remaining: 2.55s
# 37:	learn: 1.7038562	total: 842ms	remaining: 2.52s
# 38:	learn: 1.7038504	total: 861ms	remaining: 2.5s
# 39:	learn: 1.7038481	total: 879ms	remaining: 2.46s
# 40:	learn: 1.7038479	total: 897ms	remaining: 2.43s
# 41:	learn: 1.7038273	total: 912ms	remaining: 2.39s
# 42:	learn: 1.7037428	total: 928ms	remaining: 2.35s
# 43:	learn: 1.7037199	total: 942ms	remaining: 2.31s
# 44:	learn: 1.7037113	total: 956ms	remaining: 2.27s
# 45:	learn: 1.7037108	total: 971ms	remaining: 2.24s
# 46:	learn: 1.7037058	total: 985ms	remaining: 2.2s
# 47:	learn: 1.7036431	total: 999ms	remaining: 2.17s
# 48:	learn: 1.7036148	total: 1.01s	remaining: 2.13s
# 49:	learn: 1.7036071	total: 1.03s	remaining: 2.1s
# 50:	learn: 1.7036029	total: 1.05s	remaining: 2.07s
# 51:	learn: 1.7035955	total: 1.06s	remaining: 2.04s
# 52:	learn: 1.7035888	total: 1.08s	remaining: 2.02s
# 53:	learn: 1.7035843	total: 1.1s	remaining: 1.99s
# 54:	learn: 1.7035823	total: 1.11s	remaining: 1.96s
# 55:	learn: 1.7035711	total: 1.13s	remaining: 1.93s
# 56:	learn: 1.7035684	total: 1.14s	remaining: 1.9s
# 57:	learn: 1.7035679	total: 1.16s	remaining: 1.87s
# 58:	learn: 1.7035661	total: 1.17s	remaining: 1.85s
# 59:	learn: 1.7035518	total: 1.19s	remaining: 1.82s
# 60:	learn: 1.7035466	total: 1.2s	remaining: 1.79s
# 61:	learn: 1.7035351	total: 1.22s	remaining: 1.77s
# 62:	learn: 1.7035350	total: 1.23s	remaining: 1.74s
# 63:	learn: 1.7035297	total: 1.25s	remaining: 1.71s
# 64:	learn: 1.7035283	total: 1.26s	remaining: 1.69s
# 65:	learn: 1.7035201	total: 1.28s	remaining: 1.67s
# 66:	learn: 1.7035144	total: 1.3s	remaining: 1.64s
# 67:	learn: 1.7035114	total: 1.31s	remaining: 1.62s
# 68:	learn: 1.7035067	total: 1.33s	remaining: 1.6s
# 69:	learn: 1.7035054	total: 1.34s	remaining: 1.57s
# 70:	learn: 1.7034856	total: 1.36s	remaining: 1.55s
# 71:	learn: 1.7034833	total: 1.37s	remaining: 1.52s
# 72:	learn: 1.7034830	total: 1.39s	remaining: 1.5s
# 73:	learn: 1.7034800	total: 1.4s	remaining: 1.48s
# 74:	learn: 1.7034778	total: 1.42s	remaining: 1.45s
# 75:	learn: 1.7034743	total: 1.43s	remaining: 1.43s
# 76:	learn: 1.7034738	total: 1.45s	remaining: 1.41s
# 77:	learn: 1.7034703	total: 1.46s	remaining: 1.39s
# 78:	learn: 1.7034649	total: 1.48s	remaining: 1.36s
# 79:	learn: 1.7034616	total: 1.49s	remaining: 1.34s
# 80:	learn: 1.7034607	total: 1.51s	remaining: 1.32s
# 81:	learn: 1.7034596	total: 1.52s	remaining: 1.3s
# 82:	learn: 1.7034522	total: 1.54s	remaining: 1.28s
# 83:	learn: 1.7034427	total: 1.55s	remaining: 1.26s
# 84:	learn: 1.7034416	total: 1.57s	remaining: 1.24s
# 85:	learn: 1.7034388	total: 1.59s	remaining: 1.22s
# 86:	learn: 1.7034366	total: 1.6s	remaining: 1.2s
# 87:	learn: 1.7034345	total: 1.62s	remaining: 1.18s
# 88:	learn: 1.7034341	total: 1.63s	remaining: 1.15s
# 89:	learn: 1.7034337	total: 1.65s	remaining: 1.13s
# 90:	learn: 1.7034327	total: 1.66s	remaining: 1.11s
# 91:	learn: 1.7034311	total: 1.68s	remaining: 1.09s
# 92:	learn: 1.7034299	total: 1.7s	remaining: 1.08s
# 93:	learn: 1.7034295	total: 1.73s	remaining: 1.07s
# 94:	learn: 1.7034266	total: 1.76s	remaining: 1.05s
# 95:	learn: 1.7034230	total: 1.77s	remaining: 1.03s
# 96:	learn: 1.7034212	total: 1.79s	remaining: 1.01s
# 97:	learn: 1.7034201	total: 1.8s	remaining: 995ms
# 98:	learn: 1.7034197	total: 1.82s	remaining: 975ms
# 99:	learn: 1.7034191	total: 1.83s	remaining: 954ms
# 100:	learn: 1.7034178	total: 1.85s	remaining: 934ms
# 101:	learn: 1.7034171	total: 1.86s	remaining: 915ms
# 102:	learn: 1.7034163	total: 1.88s	remaining: 896ms
# 103:	learn: 1.7034150	total: 1.9s	remaining: 877ms
# 104:	learn: 1.7034147	total: 1.92s	remaining: 858ms
# 105:	learn: 1.7034080	total: 1.93s	remaining: 839ms
# 106:	learn: 1.7034058	total: 1.95s	remaining: 820ms
# 107:	learn: 1.7034040	total: 1.96s	remaining: 800ms
# 108:	learn: 1.7034039	total: 1.98s	remaining: 782ms
# 109:	learn: 1.7034036	total: 2s	remaining: 762ms
# 110:	learn: 1.7033987	total: 2.01s	remaining: 743ms
# 111:	learn: 1.7033962	total: 2.03s	remaining: 724ms
# 112:	learn: 1.7033958	total: 2.04s	remaining: 705ms
# 113:	learn: 1.7033947	total: 2.06s	remaining: 685ms
# 114:	learn: 1.7033856	total: 2.07s	remaining: 666ms
# 115:	learn: 1.7033854	total: 2.09s	remaining: 648ms
# 116:	learn: 1.7033853	total: 2.1s	remaining: 630ms
# 117:	learn: 1.7033840	total: 2.12s	remaining: 612ms
# 118:	learn: 1.7033829	total: 2.14s	remaining: 594ms
# 119:	learn: 1.7033826	total: 2.16s	remaining: 575ms
# 120:	learn: 1.7033817	total: 2.17s	remaining: 557ms
# 121:	learn: 1.7033809	total: 2.19s	remaining: 538ms
# 122:	learn: 1.7033800	total: 2.21s	remaining: 520ms
# 123:	learn: 1.7033749	total: 2.22s	remaining: 502ms
# 124:	learn: 1.7033736	total: 2.23s	remaining: 483ms
# 125:	learn: 1.7033732	total: 2.25s	remaining: 464ms
# 126:	learn: 1.7033726	total: 2.27s	remaining: 446ms
# 127:	learn: 1.7033701	total: 2.28s	remaining: 427ms
# 128:	learn: 1.7033691	total: 2.29s	remaining: 409ms
# 129:	learn: 1.7033649	total: 2.31s	remaining: 391ms
# 130:	learn: 1.7033621	total: 2.33s	remaining: 373ms
# 131:	learn: 1.7033617	total: 2.35s	remaining: 355ms
# 132:	learn: 1.7033596	total: 2.36s	remaining: 338ms
# 133:	learn: 1.7033577	total: 2.38s	remaining: 320ms
# 134:	learn: 1.7033559	total: 2.39s	remaining: 302ms
# 135:	learn: 1.7033554	total: 2.41s	remaining: 284ms
# 136:	learn: 1.7033549	total: 2.42s	remaining: 266ms
# 137:	learn: 1.7033544	total: 2.44s	remaining: 248ms
# 138:	learn: 1.7033538	total: 2.46s	remaining: 230ms
# 139:	learn: 1.7033522	total: 2.47s	remaining: 212ms
# 140:	learn: 1.7033517	total: 2.48s	remaining: 194ms
# 141:	learn: 1.7033498	total: 2.5s	remaining: 176ms
# 142:	learn: 1.7033484	total: 2.51s	remaining: 158ms
# 143:	learn: 1.7033479	total: 2.53s	remaining: 140ms
# 144:	learn: 1.7033467	total: 2.55s	remaining: 123ms
# 145:	learn: 1.7033464	total: 2.56s	remaining: 105ms
# 146:	learn: 1.7033462	total: 2.58s	remaining: 87.8ms
# 147:	learn: 1.7033446	total: 2.6s	remaining: 70.2ms
# 148:	learn: 1.7033432	total: 2.61s	remaining: 52.6ms
# 149:	learn: 1.7033423	total: 2.63s	remaining: 35ms
# 150:	learn: 1.7033407	total: 2.64s	remaining: 17.5ms
# 151:	learn: 1.7033386	total: 2.66s	remaining: 0us
# model_catboost_best Accuracy_result: 0.23868939431153902

# %% [markdown]
# ---

# %% [markdown]
# ### *D <br> <u>* *running Results:*</u>

# %%
best_model_XGBClassifier = fmin(fn=model_XGBClassifier, space=space_xgboost_clf, algo=tpe.suggest, max_evals=10)
best_model_rf_clf = fmin(fn=model_rf_clf, space=space_rf_clf, algo=tpe.suggest, max_evals=10)
best_model_GradientBoosting_clf = fmin(fn=model_GradientBoosting_clf, space=space_GradientBoosting_clf, algo=tpe.suggest, max_evals=10)
best_model_DT = fmin(fn=model_DT, space=space_DT, algo=tpe.suggest, max_evals=10)
best_model_BaggingClassifier=fmin(fn=model_Bagging, space=space_Bagging_clf, algo=tpe.suggest, max_evals=10)
best_model_catboost = fmin(fn=model_catboost, space=space_catboost_clf, algo=tpe.suggest, max_evals=10)

# %%
model_GradientBoosting_clf_best(best_model_GradientBoosting_clf)

# %%
model_XGBClassifier_best(best_model_XGBClassifier)
model_rf_clf_best(best_model_rf_clf)

model_DT_best(best_model_DT)
model_catboost_best(best_model_catboost)
model_Bagging_best(best_model_BaggingClassifier)
# Out:
# model_XGBClassifier_best Accuracy_result: 0.24870172022070755
# model_rf_clf_best Accuracy_result: 0.222303364708428
# model_DT_best Accuracy_result: 0.23931623931623933
# 0:	learn: 1.7886773	total: 29ms	remaining: 1.85s
# 1:	learn: 1.7857362	total: 53.3ms	remaining: 1.68s
# 2:	learn: 1.7829275	total: 80.1ms	remaining: 1.65s
# 3:	learn: 1.7802435	total: 105ms	remaining: 1.6s
# 4:	learn: 1.7776768	total: 133ms	remaining: 1.59s
# 5:	learn: 1.7752210	total: 162ms	remaining: 1.59s
# 6:	learn: 1.7728699	total: 188ms	remaining: 1.55s
# 7:	learn: 1.7706179	total: 215ms	remaining: 1.53s
# 8:	learn: 1.7684598	total: 242ms	remaining: 1.5s
# 9:	learn: 1.7663909	total: 268ms	remaining: 1.47s
# 10:	learn: 1.7644049	total: 293ms	remaining: 1.44s
# 11:	learn: 1.7624934	total: 318ms	remaining: 1.4s
# 12:	learn: 1.7606589	total: 345ms	remaining: 1.38s
# 13:	learn: 1.7588976	total: 375ms	remaining: 1.36s
# 14:	learn: 1.7572012	total: 402ms	remaining: 1.34s
# 15:	learn: 1.7555700	total: 429ms	remaining: 1.31s
# 16:	learn: 1.7540025	total: 455ms	remaining: 1.28s
# 17:	learn: 1.7524961	total: 481ms	remaining: 1.26s
# 18:	learn: 1.7510400	total: 507ms	remaining: 1.23s
# 19:	learn: 1.7496097	total: 531ms	remaining: 1.19s
# 20:	learn: 1.7482598	total: 557ms	remaining: 1.17s
# 21:	learn: 1.7469572	total: 584ms	remaining: 1.14s
# 22:	learn: 1.7457040	total: 613ms	remaining: 1.12s
# 23:	learn: 1.7444980	total: 641ms	remaining: 1.09s
# 24:	learn: 1.7433332	total: 667ms	remaining: 1.07s
# 25:	learn: 1.7422145	total: 693ms	remaining: 1.04s
# 26:	learn: 1.7410818	total: 716ms	remaining: 1.01s
# 27:	learn: 1.7399773	total: 741ms	remaining: 980ms
# 28:	learn: 1.7389564	total: 767ms	remaining: 952ms
# 29:	learn: 1.7379731	total: 792ms	remaining: 924ms
# 30:	learn: 1.7370132	total: 821ms	remaining: 900ms
# 31:	learn: 1.7360356	total: 850ms	remaining: 877ms
# 32:	learn: 1.7351409	total: 879ms	remaining: 852ms
# 33:	learn: 1.7342187	total: 904ms	remaining: 824ms
# 34:	learn: 1.7333289	total: 928ms	remaining: 795ms
# 35:	learn: 1.7325174	total: 953ms	remaining: 768ms
# 36:	learn: 1.7317360	total: 979ms	remaining: 741ms
# 37:	learn: 1.7309121	total: 1.01s	remaining: 716ms
# 38:	learn: 1.7301207	total: 1.04s	remaining: 692ms
# 39:	learn: 1.7294082	total: 1.07s	remaining: 667ms
# 40:	learn: 1.7286542	total: 1.09s	remaining: 641ms
# 41:	learn: 1.7279790	total: 1.12s	remaining: 615ms
# 42:	learn: 1.7273294	total: 1.15s	remaining: 587ms
# 43:	learn: 1.7266304	total: 1.17s	remaining: 560ms
# 44:	learn: 1.7259913	total: 1.2s	remaining: 535ms
# 45:	learn: 1.7253717	total: 1.23s	remaining: 508ms
# 46:	learn: 1.7247926	total: 1.26s	remaining: 482ms
# 47:	learn: 1.7242393	total: 1.3s	remaining: 460ms
# 48:	learn: 1.7236363	total: 1.34s	remaining: 438ms
# 49:	learn: 1.7231079	total: 1.38s	remaining: 415ms
# 50:	learn: 1.7225337	total: 1.42s	remaining: 391ms
# 51:	learn: 1.7220630	total: 1.46s	remaining: 366ms
# 52:	learn: 1.7215897	total: 1.51s	remaining: 342ms
# 53:	learn: 1.7210447	total: 1.55s	remaining: 316ms
# 54:	learn: 1.7205721	total: 1.59s	remaining: 290ms
# 55:	learn: 1.7200344	total: 1.63s	remaining: 263ms
# 56:	learn: 1.7195490	total: 1.68s	remaining: 235ms
# 57:	learn: 1.7190556	total: 1.72s	remaining: 207ms
# 58:	learn: 1.7186706	total: 1.76s	remaining: 179ms
# 59:	learn: 1.7182211	total: 1.81s	remaining: 151ms
# 60:	learn: 1.7177501	total: 1.85s	remaining: 121ms
# 61:	learn: 1.7172955	total: 1.89s	remaining: 91.4ms
# 62:	learn: 1.7169050	total: 1.93s	remaining: 61.3ms
# 63:	learn: 1.7165408	total: 1.97s	remaining: 30.8ms
# 64:	learn: 1.7161180	total: 2.02s	remaining: 0us
# model_catboost_best Accuracy_result: 0.2553283565941794
# model_Bagging_best Accuracy_result: 0.26287460781131666

# %% [markdown]
# ### *D.1 <br> <u>* *best Results:*</u>
#
# > *XGBClassifier has the highest accuracy score*

# %%
y_model_rf_clf_best=[]
Accuracy_list=[]
model_opt = Pipeline(
        steps=[
            #('preprocessor', preprocessor),
              ("RandomForestClassifier",RandomForestClassifier(              
                                    n_estimators=int(best_model_rf_clf['n_estimators']),
                                    #criterion=int(best_model_rf_clf['criterion']),                                                       
                                    max_depth=int(best_model_rf_clf['max_depth']),
                                    min_samples_split=float(best_model_rf_clf['min_samples_split']),
                                    min_samples_leaf=float(best_model_rf_clf['min_samples_leaf']),
                                    #max_features=float(space_rf_clf["max_features"]),
                                    bootstrap=int(best_model_rf_clf['bootstrap'])

                                    ))

                                    ])
                                                                               
model_opt.fit(xtrain,ytrain)
Accuracy_result=accuracy_score(ytest,model_opt.predict(xtest))
y_pred=model_opt.predict(xtest)
y_model_rf_clf_best.append(y_pred)

Accuracy_result=accuracy_score(ytest,y_pred)
Accuracy_list.append(Accuracy_result)

# %%
print(classification_report(ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1720
#            1       0.00      0.00      0.00      3914
#            2       0.26      0.27      0.27      4693
#            3       0.24      0.76      0.36      4847
#            4       0.00      0.00      0.00      3233
#            5       0.00      0.00      0.00      1950
#
#     accuracy                           0.24     20357
#    macro avg       0.08      0.17      0.10     20357
# weighted avg       0.12      0.24      0.15     20357

# %%
unique_labels(ytest)
labels=unique_labels(ytest)
col_names=[f"predicted{label}"for label in labels ]
index_names=[f"Actual{label}"for label in labels ]
pd.DataFrame(confusion_matrix(ytest, y_pred),columns=col_names,index=index_names)
# Out:
#          predicted0  predicted1  predicted2  predicted3  predicted4  \
# Actual0           0           0         336        1384           0
# Actual1           0           0        1024        2890           0
# Actual2           0           0        1276        3417           0
# Actual3           0           0        1182        3665           0
# Actual4           0           0         700        2533           0
# Actual5           0           0         312        1638           0
#
#          predicted5
# Actual0           0
# Actual1           0
# Actual2           0
# Actual3           0
# Actual4           0
# Actual5           0

# %%
matplotlib.rcParams["figure.figsize"]=(25,5)
ConfusionMatrixDisplay(confusion_matrix(ytest,y_pred)).plot()

# %%
from sklearn.multiclass import OneVsRestClassifier

# %%
matplotlib.rcParams["figure.figsize"]=(25,10)
clf = OneVsRestClassifier(RandomForestClassifier(              
                                    n_estimators=int(best_model_rf_clf['n_estimators']),
                                    #criterion=int(best_model_rf_clf['criterion']),                                                       
                                    max_depth=int(best_model_rf_clf['max_depth']),
                                    min_samples_split=float(best_model_rf_clf['min_samples_split']),
                                    min_samples_leaf=float(best_model_rf_clf['min_samples_leaf']),
                                    #max_features=float(space_rf_clf["max_features"]),
                                    bootstrap=int(best_model_rf_clf['bootstrap'])))


clf.fit(xtrain, ytrain)
pred = clf.predict(xtest)
pred_prob = clf.predict_proba(xtest)

# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 6

random_probs = [0 for i in range(len(ytest))]
p_fpr, p_tpr, _ = roc_curve(ytest, random_probs, pos_label=1)
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(ytest, pred_prob[:,i], pos_label=i)
    
# plotting    
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Class age categoty ==1 vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Class age categoty ==2 vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='red', label='Class age categoty ==3 vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='yellow', label='Class age categoty ==4 vs Rest')
plt.plot(fpr[4], tpr[4], linestyle='--',color='DeepPink', label='Class age categoty ==5 vs Rest')
plt.plot(fpr[5], tpr[5], linestyle='--',color='DarkViolet', label='Class age categoty ==6 vs Rest')

plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
#plt.savefig('Multiclass ROC',dpi=300);

# %%
plt.subplot(231)
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange')
plt.legend(['sensitivity /recall','Class agecat :1  vs Rest'])

plt.subplot(232)
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green')
plt.legend(['sensitivity /recall','Class agecat :2  vs Rest'])

plt.subplot(233)
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[2], tpr[2], linestyle='--',color='red')
plt.legend(['sensitivity /recall','Class agecat :3  vs Rest'])

plt.subplot(234)
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[3], tpr[3], linestyle='--',color='red')
plt.legend(['sensitivity /recall','Class agecat :4  vs Rest'])

plt.subplot(235)
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[4], tpr[4], linestyle='--',color='red')
plt.legend(['sensitivity /recall','Class agecat :5  vs Rest'])

plt.subplot(236)
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.plot(fpr[5], tpr[5], linestyle='--',color='red')
plt.legend(['sensitivity /recall','Class agecat :6  vs Rest'])
